# %% [markdown]
# ## Fixed Random Seed

# %%
import numpy as np
import random
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import optuna
from prettytable import PrettyTable
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
from sklearn.base import clone, BaseEstimator, TransformerMixin
from category_encoders import TargetEncoder
from catboost import CatBoostRegressor
import statsmodels.api as sm

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

TARGET = "Income"

# %% [markdown]
# ## 데이터 불러오기 및 확인

# %%
import pandas as pd

train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

display(train.head(3))
display(test.head(3))
# Out:
#             ID  Age Gender                Education_Status Employment_Status  \
# 0  TRAIN_00000   63      M                    Middle (7-8)         Full-Time
# 1  TRAIN_00001   37      M  Associates degree (Vocational)         Full-Time
# 2  TRAIN_00002   58      F                   High graduate         Full-Time
#
#    Working_Week (Yearly)              Industry_Status  \
# 0                      4              Social Services
# 1                     52                Entertainment
# 2                     52  Manufacturing (Non-durable)
#
#                   Occupation_Status   Race Hispanic_Origin  ... Citizenship  \
# 0                          Services  White       All other  ...      Native
# 1                          Services  White       All other  ...      Native
# 2  Admin Support (include Clerical)  Black       All other  ...      Native
#
#   Birth_Country Birth_Country (Father) Birth_Country (Mother)  \
# 0            US                     US                     US
# 1            US                     US                     US
# 2            US                     US                     US
#
#                                     Tax_Status Gains Losses Dividends  \
# 0                                     Nonfiler     0      0         0
# 1                                       Single     0      0         0
# 2  Married Filling Jointly both under 65 (MFJ)  3411      0         0
#
#    Income_Status  Income
# 0        Unknown     425
# 1   Under Median       0
# 2   Under Median     860
#
# [3 rows x 23 columns]
#           ID  Age Gender  Education_Status         Employment_Status  \
# 0  TEST_0000   79      M       High Junior  Children or Armed Forces
# 1  TEST_0001   47      M  Elementary (5-6)  Children or Armed Forces
# 2  TEST_0002   18      F       High Junior  Children or Armed Forces
#
#    Working_Week (Yearly)              Industry_Status Occupation_Status  \
# 0                      0  Not in universe or children           Unknown
# 1                      0  Not in universe or children           Unknown
# 2                     52                       Retail          Services
#
#     Race Hispanic_Origin  ...  Household_Summary Citizenship Birth_Country  \
# 0  White       All other  ...        Householder      Native            US
# 1  White   Other Spanish  ...  Child 18 or older      Native            US
# 2  White       All other  ...  Child 18 or older      Native            US
#
#   Birth_Country (Father) Birth_Country (Mother) Tax_Status Gains Losses  \
# 0                Unknown                Unknown     Single     0      0
# 1                     US                     US   Nonfiler     0      0
# 2                     US                     US     Single     0      0
#
#    Dividends  Income_Status
# 0          0   Under Median
# 1          0   Under Median
# 2          0   Under Median
#
# [3 rows x 22 columns]

# %%
train.describe()
# Out:
#                 Age  Working_Week (Yearly)         Gains        Losses  \
# count  20000.000000           20000.000000  20000.000000  20000.000000
# mean      35.632500              34.943050    383.129500     40.202150
# std       17.994414              22.254592   4144.247487    279.182677
# min        0.000000               0.000000      0.000000      0.000000
# 25%       23.000000               7.000000      0.000000      0.000000
# 50%       34.000000              52.000000      0.000000      0.000000
# 75%       47.000000              52.000000      0.000000      0.000000
# max       90.000000              52.000000  99999.000000   4356.000000
#
#           Dividends        Income
# count  20000.000000  20000.000000
# mean     123.451450    554.565250
# std     1206.949429    701.553155
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000    500.000000
# 75%        0.000000    875.000000
# max    45000.000000   9999.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      20000 non-null  object
#  1   Age                     20000 non-null  int64
#  2   Gender                  20000 non-null  object
#  3   Education_Status        20000 non-null  object
#  4   Employment_Status       20000 non-null  object
#  5   Working_Week (Yearly)   20000 non-null  int64
#  6   Industry_Status         20000 non-null  object
#  7   Occupation_Status       20000 non-null  object
#  8   Race                    20000 non-null  object
#  9   Hispanic_Origin         20000 non-null  object
#  10  Martial_Status          20000 non-null  object
#  11  Household_Status        20000 non-null  object
#  12  Household_Summary       20000 non-null  object
#  13  Citizenship             20000 non-null  object
#  14  Birth_Country           20000 non-null  object
#  15  Birth_Country (Father)  20000 non-null  object
#  16  Birth_Country (Mother)  20000 non-null  object
#  17  Tax_Status              20000 non-null  object
#  18  Gains                   20000 non-null  int64
#  19  Losses                  20000 non-null  int64
#  20  Dividends               20000 non-null  int64
#  21  Income_Status           20000 non-null  object
#  22  Income                  20000 non-null  int64
# dtypes: int64(6), object(17)
# memory usage: 3.5+ MB

# %%
for col in train[['Gender', 'Education_Status', 'Employment_Status', 'Working_Week (Yearly)', 'Industry_Status', 'Occupation_Status', 'Race', 'Hispanic_Origin', 'Martial_Status','Household_Status','Household_Summary','Citizenship','Birth_Country','Birth_Country (Father)','Birth_Country (Mother)','Tax_Status','Gains','Losses','Dividends','Income_Status','Income']].columns:

    print(train[col].value_counts())
# Out:
# F    10472
# M     9528
# Name: Gender, dtype: int64
# High graduate                     6494
# College                           3794
# Children                          2208
# Bachelors degree                  1956
# High Junior                        820
# High Sophomore                     799
# Associates degree (Vocational)     741
# Associates degree (Academic)       609
# High Freshman                      555
# Middle (7-8)                       548
# Masters degree                     505
# Elementary (5-6)                   317
# High Senior                        242
# Elementary (1-4)                   150
# Professional degree                111
# Doctorate degree                    87
# Kindergarten                        64
# Name: Education_Status, dtype: int64
# Children or Armed Forces         11142
# Full-Time                         6588
# Not Working                       1221
# Choice Part-Time                   593
# Part-Time (Usually Part-Time)      158
# Seeking Full-Time                  121
# Part-Time (Usually Full-Time)      100
# Seeking Part-Time                   77
# Name: Employment_Status, dtype: int64
# 52    10613
# 0      4720
# 40      440
# 50      363
# 48      313
# 26      283
# 20      213
# 12      209
# 30      207
# 36      181
# 32      139
# 44      138
# 16      134
# 51      134
# 8       129
# 49      117
# 35      115
# 24      105
# 46       97
# 45       95
# 42       94
# 39       87
# 28       79
# 4        78
# 10       67
# 25       63
# 43       58
# 38       57
# 6        55
# 13       54
# 15       48
# 18       46
# 22       45
# 47       43
# 2        41
# 1        34
# 14       34
# 5        32
# 3        32
# 17       30
# 7        28
# 34       23
# 9        23
# 37       20
# 19       13
# 41       13
# 27       12
# 11       10
# 21        9
# 29        8
# 23        8
# 31        6
# 33        5
# Name: Working_Week (Yearly), dtype: int64
# Not in universe or children                     4688
# Retail                                          3149
# Manufacturing (Durable)                         1575
# Manufacturing (Non-durable)                     1223
# Education                                       1041
# Business & Repair                                847
# Medical (except Hospitals)                       838
# Construction                                     832
# Hospitals                                        821
# Finance Insurance & Real Estate                  727
# Transportation                                   693
# Public Administration                            641
# Other professional services                      477
# Wholesale                                        450
# Personal Services (except Private Household)     429
# Social Services                                  367
# Entertainment                                    278
# Agriculture                                      268
# Utilities & Sanitary                             202
# Communications                                   195
# Private Household Services                       125
# Mining                                           107
# Forestry & Fisheries                              26
# Armed Forces                                       1
# Name: Industry_Status, dtype: int64
# Unknown                             4688
# Admin Support (include Clerical)    2709
# Services                            2313
# Craft & Repair                      1869
# Sales                               1692
# Professional                        1488
# Machine Operators & Inspectors      1383
# Management                          1111
# Handlers/Cleaners                    837
# Transportation                       690
# Technicians & Support                558
# Farming & Forestry & Fishing         296
# Protective Services                  260
# Private Household Services           105
# Armed Forces                           1
# Name: Occupation_Status, dtype: int64
# White                           16845
# Black                            2122
# Asian/Pacific                     511
# Other                             296
# Native American/Aleut/Eskimo      226
# Name: Race, dtype: int64
#  All other                    17769
#  Mexican-American               654
#  Mexican (Mexicano)             624
#  Central or South American      325
#  Puerto Rican                   243
#  Other Spanish                  201
#  Cuban                           76
#  NA                              59
#  Chicano                         27
#  Do not know                     22
# Name: Hispanic_Origin, dtype: int64
# Married                         9554
# Single                          7380
# Divorced                        1633
# Widowed                          756
# Separated                        436
# Married (Spouse Absent)          171
# Married (Armed Force Spouse)      70
# Name: Martial_Status, dtype: int64
# Householder                                                               6087
# Spouse of householder                                                     4794
# Child <18 never marr not in subfamily                                     2670
# Nonfamily householder                                                     2465
# Child 18+ never marr Not in a subfamily                                   1860
# Secondary individual                                                       845
# Other Rel 18+ never marr not in subfamily                                  195
# Other Rel 18+ ever marr not in subfamily                                   154
# Child 18+ ever marr Not in a subfamily                                     118
# Child 18+ ever married Responsible Person of subfamily                     101
# Child 18+ never married Responsible Person of subfamily                     96
# Grandchild <18 never married child of subfamily Responsible Person          88
# Responsible Person of unrelated subfamily                                   87
# Other Relative 18+ ever married Responsible Person of subfamily             77
# Other Relative 18+ spouse of subfamily Responsible Person                   73
# Grandchild 18+ never marr not in subfamily                                  63
# Grandchild <18 never marr not in subfamily                                  43
# Child under 18 of Responsible Person of unrelated subfamily                 39
# Other Rel <18 never marr not in subfamily                                   36
# Other Relative <18 never married child of subfamily Responsible Person      27
# In group quarters                                                           26
# Other Relative 18+ never married Responsible Person of subfamily            19
# Child 18+ spouse of subfamily Responsible Person                            16
# Child <18 never married Responsible Person of subfamily                      8
# Child <18 ever marr not in subfamily                                         3
# Spouse of Responsible Person of unrelated subfamily                          3
# Grandchild 18+ ever marr not in subfamily                                    3
# Grandchild 18+ spouse of subfamily Responsible Person                        1
# Grandchild 18+ ever married Responsible Person of subfamily                  1
# Child <18 ever married Responsible Person of subfamily                       1
# Other Relative <18 ever married Responsible Person of subfamily              1
# Name: Household_Status, dtype: int64
# Householder                             8552
# Spouse of householder                   4794
# Child under 18 never married            2679
# Child 18 or older                       2192
# Nonrelative of householder               974
# Other relative of householder            781
# Group Quarters- Secondary individual      24
# Child under 18 ever married                4
# Name: Household_Summary, dtype: int64
# Native                                         17825
# Foreign-born (Non-US Citizen)                   1258
# Foreign-born (Naturalized US Citizen)            588
# Native (Born Abroad)                             197
# Native (Born in Puerto Rico or US Outlying)      132
# Name: Citizenship, dtype: int64
# US                              17825
# Mexico                            540
# Unknown                           330
# Puerto-Rico                       117
# Philippines                       112
# Germany                            90
# Canada                             75
# El-Salvador                        68
# Cuba                               58
# India                              55
# Dominican-Republic                 49
# England                            47
# Poland                             45
# Jamaica                            45
# Columbia                           36
# Italy                              35
# South Korea                        31
# Vietnam                            31
# Ecuador                            31
# Japan                              30
# Portugal                           29
# Nicaragua                          28
# China                              28
# Guatemala                          28
# Haiti                              25
# Iran                               24
# Peru                               22
# Ireland                            21
# Hong Kong                          16
# Outlying-U S (Guam USVI etc)       15
# France                             14
# Honduras                           14
# Greece                             13
# Laos                               11
# Taiwan                             11
# Thailand                           10
# Cambodia                            8
# Trinadad&Tobago                     8
# Yugoslavia                          7
# Scotland                            7
# Panama                              4
# Hungary                             4
# Holand-Netherlands                  3
# Name: Birth_Country, dtype: int64
# US                              16563
# Mexico                            845
# Unknown                           581
# Puerto-Rico                       206
# Italy                             197
# Canada                            128
# Philippines                       121
# Poland                            110
# Dominican-Republic                 99
# Germany                            92
# El-Salvador                        83
# Cuba                               78
# England                            69
# China                              69
# India                              68
# Jamaica                            56
# Ireland                            47
# Portugal                           47
# Columbia                           45
# Ecuador                            42
# Haiti                              37
# South Korea                        34
# Guatemala                          33
# Greece                             33
# Vietnam                            32
# Nicaragua                          30
# Japan                              28
# Scotland                           27
# Peru                               26
# Iran                               25
# Hungary                            22
# Yugoslavia                         18
# France                             17
# Cambodia                           13
# Laos                               12
# Honduras                           12
# Outlying-U S (Guam USVI etc)       12
# Trinadad&Tobago                    11
# Taiwan                             10
# Hong Kong                           8
# Thailand                            7
# Holand-Netherlands                  5
# Panama                              2
# Name: Birth_Country (Father), dtype: int64
# US                              16594
# Mexico                            849
# Unknown                           517
# Puerto-Rico                       194
# Canada                            159
# Italy                             152
# Philippines                       128
# Germany                           117
# Poland                            104
# El-Salvador                        99
# England                            88
# Dominican-Republic                 75
# Cuba                               73
# India                              67
# China                              60
# Ireland                            58
# Jamaica                            56
# Columbia                           45
# Ecuador                            44
# Portugal                           44
# South Korea                        41
# Vietnam                            39
# Japan                              37
# Guatemala                          36
# Nicaragua                          35
# Haiti                              34
# Peru                               26
# Iran                               26
# France                             25
# Greece                             23
# Hungary                            18
# Yugoslavia                         17
# Honduras                           17
# Scotland                           15
# Outlying-U S (Guam USVI etc)       14
# Trinadad&Tobago                    14
# Thailand                           12
# Cambodia                           11
# Taiwan                             11
# Hong Kong                          10
# Laos                                8
# Panama                              4
# Holand-Netherlands                  4
# Name: Birth_Country (Mother), dtype: int64
# Married Filling Jointly both under 65 (MFJ)                 8588
# Single                                                      5547
# Nonfiler                                                    3874
# Head of Household (HOH)                                     1217
# Married Filling Jointly both over 65 (MFJ)                   469
# Married Filling Jointly one over 65 & one under 65 (MFJ)     305
# Name: Tax_Status, dtype: int64
# 0        19217
# 7298        73
# 15024       60
# 7688        54
# 5178        35
#          ...
# 2290         1
# 1455         1
# 3456         1
# 7430         1
# 2993         1
# Name: Gains, Length: 106, dtype: int64
# 0       19568
# 1902       43
# 1887       41
# 1977       35
# 1602       26
#         ...
# 2489        1
# 2231        1
# 2201        1
# 1911        1
# 3175        1
# Name: Losses, Length: 86, dtype: int64
# 0       17928
# 100       134
# 1000       86
# 500        86
# 50         86
#         ...
# 392         1
# 528         1
# 107         1
# 59          1
# 456         1
# Name: Dividends, Length: 420, dtype: int64
# Under Median    13237
# Unknown          6026
# Over Median       737
# Name: Income_Status, dtype: int64
# 0       8697
# 500      743
# 700      550
# 600      547
# 800      526
#         ...
# 543        1
# 1713       1
# 1602       1
# 1722       1
# 2373       1
# Name: Income, Length: 1228, dtype: int64

# %%
class ColumnEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, cols):
        self.cols = cols
        
    def fit_transform(self, X, y=None):
        self.encoders = {}
        for col in self.cols:
            le = TargetEncoder()
            X[col] = le.fit_transform(X[col], y)
            self.encoders[col] = le
        return X
    
    def transform(self, X):
        for col in self.cols:
            X[col] = self.encoders[col].transform(X[col])
        return X

# %% [markdown]
# ## 데이터 전처리 1 : 학습 및 추론 데이터 설정

# %%
sns.histplot(train['Income'], linewidth=0.5, kde=True)
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
# 이상치 확인
fig, axes = plt.subplots(2, 3, figsize=(15, 5))

sns.boxplot(data=train, y='Age', ax=axes[0][0])
sns.boxplot(data=train, y='Working_Week (Yearly)', ax=axes[0][1])
sns.boxplot(data=train, y='Gains', ax=axes[0][2])
sns.boxplot(data=train, y='Losses', ax=axes[1][0])
sns.boxplot(data=train, y='Dividends', ax=axes[1][1])
sns.boxplot(data=train, y='Income', ax=axes[1][2])

plt.tight_layout()
plt.show()

# %%
# 이상치 확인
fig, axes = plt.subplots(2, 3, figsize=(15, 5))

sns.scatterplot(data=train, y='Income', x='Age', ax=axes[0][0])
sns.scatterplot(data=train, y='Income', x='Working_Week (Yearly)', ax=axes[0][1])
sns.scatterplot(data=train, y='Income', x='Gains', ax=axes[0][2])
sns.scatterplot(data=train, y='Income', x='Losses', ax=axes[1][0])
sns.scatterplot(data=train, y='Income', x='Dividends', ax=axes[1][1])
sns.scatterplot(data=train, y='Income', x='Income', ax=axes[1][2])

plt.tight_layout()
plt.show()

# %%
# train에서 컬럼의 unique한 값의 개수가 20개 이하인 컬럼만 선택
selected_cols = [col for col in train.columns if len(train[col].unique()) <= 20]
# target과의 관계를 살펴보기 위해, target을 분리하여 데이터를 분석
train_eda = train[selected_cols + [TARGET]].copy()

plt.figure(figsize=(15, 9))
for i, col in enumerate(selected_cols):
    plt.subplot(4, 3, i+1)
    sns.boxplot(x=col, y=TARGET, data=train_eda)
    plt.tight_layout()
# Out:
# <ipython-input-36-6785f3224427>:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# <ipython-input-36-6785f3224427>:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# <ipython-input-36-6785f3224427>:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# <ipython-input-36-6785f3224427>:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# <ipython-input-36-6785f3224427>:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# <ipython-input-36-6785f3224427>:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# <ipython-input-36-6785f3224427>:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# <ipython-input-36-6785f3224427>:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# <ipython-input-36-6785f3224427>:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# <ipython-input-36-6785f3224427>:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
def prettify_df(df):
    table = PrettyTable()
    table.field_names = df.columns

    for row in df.values:
        table.add_row(row)
    print(table)

# %%
# Train Data
print("Train Data")
print(f"Total number of rows: {len(train)}")
print(f"Total number of columns: {train.shape[1]}\n")

# Test Data
print("Test Data")
print(f"Total number of rows: {len(test)}")
print(f"Total number of columns:{test.shape[1]}")
# Out:
# Train Data
# Total number of rows: 20000
# Total number of columns: 23
#
# Test Data
# Total number of rows: 10000
# Total number of columns:22

# %% [markdown]
# ### Income 예측이 음수 값인 경우 0으로 변환
#
# ### Income = 0 인 경우
# - Industry_Status : Not in universe
# - Occupation_Status : Unknown
# - Employment_Status : Not Working
# - Education_Status : Children

# %%
skf = StratifiedKFold(n_splits=5)

def cross_val_model(train, estimators,cv = skf, verbose = True):
    X = train.copy()
    y = X.pop(TARGET)

    test_predictions = np.zeros((len(test)))

    val_scores = []
    for fold, (train_ind, valid_ind) in enumerate(skf.split(X,y)):
        model = clone(estimators)
        
        X_train, y_train = X.iloc[train_ind], y.iloc[train_ind]
        X_valid, y_valid = X.iloc[valid_ind], y.iloc[valid_ind]
        
        model.fit(X_train, y_train)

        if verbose:
            print("-" * 100)
            print(f"Fold: {fold}")

            y_preds_t = model.predict(X_train)
            y_preds_t[y_preds_t < 0] = 0
            
            y_preds_v = model.predict(X_valid)
            y_preds_v[y_preds_v < 0] = 0

            print(f"Train Accuracy Score:-{mean_squared_error(y_train, y_preds_t, squared=False)}")
            print(f"Valid Accuracy Score:-{mean_squared_error(y_valid, y_preds_v, squared=False)}")
            print("-" * 100)

        test_predictions += model.predict(test) / 5
        y_preds = model.predict(X_valid)
        y_preds[y_preds < 0] = 0
        y_preds[X_valid['Industry_Status'] == 'Not in universe'] = 0
        y_preds[X_valid['Occupation_Status'] == 'Unknown'] = 0
        y_preds[X_valid['Employment_Status'] == 'Not Working'] = 0
        y_preds[X_valid['Education_Status'] == 'Children'] = 0
        

        val_scores.append(mean_squared_error(y_valid,y_preds, squared=False))

    if verbose: 
        print(f"RMSE Score: {np.array(val_scores).mean()}")

    test_predictions[test_predictions < 0] = 0
    test_predictions[test['Industry_Status'] == 'Not in universe'] = 0
    test_predictions[test['Occupation_Status'] == 'Unknown'] = 0
    test_predictions[test['Employment_Status'] == 'Not Working'] = 0
    test_predictions[test['Education_Status'] == 'Children'] = 0
    
    return val_scores, test_predictions

# %%
# train.head()

train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      20000 non-null  object
#  1   Age                     20000 non-null  int64
#  2   Gender                  20000 non-null  object
#  3   Education_Status        20000 non-null  object
#  4   Employment_Status       20000 non-null  object
#  5   Working_Week (Yearly)   20000 non-null  int64
#  6   Industry_Status         20000 non-null  object
#  7   Occupation_Status       20000 non-null  object
#  8   Race                    20000 non-null  object
#  9   Hispanic_Origin         20000 non-null  object
#  10  Martial_Status          20000 non-null  object
#  11  Household_Status        20000 non-null  object
#  12  Household_Summary       20000 non-null  object
#  13  Citizenship             20000 non-null  object
#  14  Birth_Country           20000 non-null  object
#  15  Birth_Country (Father)  20000 non-null  object
#  16  Birth_Country (Mother)  20000 non-null  object
#  17  Tax_Status              20000 non-null  object
#  18  Gains                   20000 non-null  int64
#  19  Losses                  20000 non-null  int64
#  20  Dividends               20000 non-null  int64
#  21  Income_Status           20000 non-null  object
#  22  Income                  20000 non-null  int64
# dtypes: int64(6), object(17)
# memory usage: 3.5+ MB

# %%
# ID
# Age
# Gender
# Education_Status
# Employment_Status
# Working_Week (Yearly)
# Industry_Status
# Occupation_Status
# Race
# Hispanic_Origin
# Martial_Status
# Household_Status
# Household_Summary
# Citizenship
# Birth_Country
# Birth_Country (Father)
# Birth_Country (Mother)
# Tax_Status
# Gains
# Losses
# Dividends
# Income_Status
# Income

# %%
for df in [train, test]:
    df['Working_Week_rate'] = df['Working_Week (Yearly)'] / 52

    df['Edu_Emp'] = df['Education_Status'] + '_' + df['Employment_Status']

    df['Ind_Occ'] = df['Industry_Status'] + '_' + df['Occupation_Status']

    # df['Race_Hisp'] = df['Race'] + '_' + df['Hispanic_Origin']

    df['Tax_Income'] = df['Tax_Status'] + '_' + df['Income_Status']

    # df['Birth_Country_F_M'] = df['Birth_Country (Father)'] + '_' + df['Birth_Country (Mother)']

    df['Age * Work%'] = df['Age'] * df['Working_Week_rate']
    
    df['log Gains'] = np.log(df['Gains']+1)

    df['log Losses'] = np.log(df['Losses']+1)

    df['log Dividends'] = np.log(df['Dividends']+1)

# %%
# 불필요한 컬럼 제거 및 중복 데이터 제거
drop_cols = ['ID', 'Birth_Country (Father)', 'Birth_Country (Mother)', 'Gains', 'Losses', 'Dividends', 'Household_Status']
train.drop(drop_cols, axis = 1, inplace = True)
test.drop(drop_cols, axis = 1, inplace = True)

train = train.drop_duplicates()
train.reset_index(drop=True, inplace=True)

# %%
# null 및 고유 카운트 확인
train_copy = train.copy()
tmp = pd.DataFrame(index=train_copy.columns)
tmp['count'] = train_copy.count()
tmp['dtype'] = train_copy.dtypes
tmp['nunique'] = train_copy.nunique()
tmp['%nunique'] = (tmp['nunique']/len(train_copy))*100
tmp['%null'] = (train_copy.isnull().sum()/len(train_copy))*100
# tmp에서 column type이 object가 아닌 것의 최소를 구하기, column type이 object이면 'no'로 채움
tmp['min'] = [train_copy[col].min() if train_copy[col].dtype != 'object' else None for col in train_copy.columns]
tmp['max'] = [train_copy[col].max() if train_copy[col].dtype != 'object' else None for col in train_copy.columns]
tmp

tmp.reset_index(inplace=True)
tmp = tmp.rename(columns = {"index":"Column Name"})
tmp = tmp.round(3)
prettify_df(tmp)
del tmp, train_copy
# Out:
# +-----------------------+-------+---------+---------+----------+-------+-----+--------+
# |      Column Name      | count |  dtype  | nunique | %nunique | %null | min |  max   |
# +-----------------------+-------+---------+---------+----------+-------+-----+--------+
# |          Age          | 18275 |  int64  |    91   |  0.498   |  0.0  | 0.0 |  90.0  |
# |         Gender        | 18275 |  object |    2    |  0.011   |  0.0  | nan |  nan   |
# |    Education_Status   | 18275 |  object |    17   |  0.093   |  0.0  | nan |  nan   |
# |   Employment_Status   | 18275 |  object |    8    |  0.044   |  0.0  | nan |  nan   |
# | Working_Week (Yearly) | 18275 |  int64  |    53   |   0.29   |  0.0  | 0.0 |  52.0  |
# |    Industry_Status    | 18275 |  object |    24   |  0.131   |  0.0  | nan |  nan   |
# |   Occupation_Status   | 18275 |  object |    15   |  0.082   |  0.0  | nan |  nan   |
# |          Race         | 18275 |  object |    5    |  0.027   |  0.0  | nan |  nan   |
# |    Hispanic_Origin    | 18275 |  object |    10   |  0.055   |  0.0  | nan |  nan   |
# |     Martial_Status    | 18275 |  object |    7    |  0.038   |  0.0  | nan |  nan   |
# |   Household_Summary   | 18275 |  object |    8    |  0.044   |  0.0  | nan |  nan   |
# |      Citizenship      | 18275 |  object |    5    |  0.027   |  0.0  | nan |  nan   |
# |     Birth_Country     | 18275 |  object |    43   |  0.235   |  0.0  | nan |  nan   |
# |       Tax_Status      | 18275 |  object |    6    |  0.033   |  0.0  | nan |  nan   |
# |     Income_Status     | 18275 |  object |    3    |  0.016   |  0.0  | nan |  nan   |
# |         Income        | 18275 |  int64  |   1228  |   6.72   |  0.0  | 0.0 | 9999.0 |
# |   Working_Week_rate   | 18275 | float64 |    53   |   0.29   |  0.0  | 0.0 |  1.0   |
# |        Edu_Emp        | 18275 |  object |   117   |   0.64   |  0.0  | nan |  nan   |
# |        Ind_Occ        | 18275 |  object |   244   |  1.335   |  0.0  | nan |  nan   |
# |       Tax_Income      | 18275 |  object |    18   |  0.098   |  0.0  | nan |  nan   |
# |      Age * Work%      | 18275 | float64 |   1079  |  5.904   |  0.0  | 0.0 |  90.0  |
# |       log Gains       | 18275 | float64 |   106   |   0.58   |  0.0  | 0.0 | 11.513 |
# |       log Losses      | 18275 | float64 |    86   |  0.471   |  0.0  | 0.0 |  8.38  |
# |     log Dividends     | 18275 | float64 |   420   |  2.298   |  0.0  | 0.0 | 10.714 |
# +-----------------------+-------+---------+---------+----------+-------+-----+--------+

# %%
# column encoder
categorical_columns = train.select_dtypes(include=['object']).columns

train = train.copy()
ce = ColumnEncoder(categorical_columns)
train = ce.fit_transform(train, train[TARGET])
test = ce.transform(test)

# %%
# null 및 고유 카운트 확인
train_copy = train.copy()
tmp = pd.DataFrame(index=train_copy.columns)
tmp['count'] = train_copy.count()
tmp['dtype'] = train_copy.dtypes
tmp['nunique'] = train_copy.nunique()
tmp['%nunique'] = (tmp['nunique']/len(train_copy))*100
tmp['%null'] = (train_copy.isnull().sum()/len(train_copy))*100
# tmp에서 column type이 object가 아닌 것의 최소를 구하기, column type이 object이면 'no'로 채움
tmp['min'] = [train_copy[col].min() if train_copy[col].dtype != 'object' else None for col in train_copy.columns]
tmp['max'] = [train_copy[col].max() if train_copy[col].dtype != 'object' else None for col in train_copy.columns]
tmp

tmp.reset_index(inplace=True)
tmp = tmp.rename(columns = {"index":"Column Name"})
tmp = tmp.round(3)
prettify_df(tmp)
del tmp, train_copy
# Out:
# +-----------------------+-------+---------+---------+----------+-------+---------+----------+
# |      Column Name      | count |  dtype  | nunique | %nunique | %null |   min   |   max    |
# +-----------------------+-------+---------+---------+----------+-------+---------+----------+
# |          Age          | 18275 |  int64  |    91   |  0.498   |  0.0  |   0.0   |   90.0   |
# |         Gender        | 18275 | float64 |    2    |  0.011   |  0.0  | 538.063 | 681.899  |
# |    Education_Status   | 18275 | float64 |    17   |  0.093   |  0.0  |   0.0   |  867.27  |
# |   Employment_Status   | 18275 | float64 |    8    |  0.044   |  0.0  |   0.0   | 877.905  |
# | Working_Week (Yearly) | 18275 |  int64  |    53   |   0.29   |  0.0  |   0.0   |   52.0   |
# |    Industry_Status    | 18275 | float64 |    24   |  0.131   |  0.0  |   0.0   | 1115.292 |
# |   Occupation_Status   | 18275 | float64 |    15   |  0.082   |  0.0  |   0.0   | 1002.418 |
# |          Race         | 18275 | float64 |    5    |  0.027   |  0.0  | 416.839 | 618.099  |
# |    Hispanic_Origin    | 18275 | float64 |    10   |  0.055   |  0.0  | 254.999 | 632.506  |
# |     Martial_Status    | 18275 | float64 |    7    |  0.038   |  0.0  | 333.091 | 917.903  |
# |   Household_Summary   | 18275 | float64 |    8    |  0.044   |  0.0  | 157.986 | 701.522  |
# |      Citizenship      | 18275 | float64 |    5    |  0.027   |  0.0  |  386.17 | 664.628  |
# |     Birth_Country     | 18275 | float64 |    43   |  0.235   |  0.0  | 326.431 |  836.45  |
# |       Tax_Status      | 18275 | float64 |    6    |  0.033   |  0.0  | 106.404 | 744.666  |
# |     Income_Status     | 18275 | float64 |    3    |  0.016   |  0.0  | 591.983 | 941.084  |
# |         Income        | 18275 |  int64  |   1228  |   6.72   |  0.0  |   0.0   |  9999.0  |
# |   Working_Week_rate   | 18275 | float64 |    53   |   0.29   |  0.0  |   0.0   |   1.0    |
# |        Edu_Emp        | 18275 | float64 |   104   |  0.569   |  0.0  |   0.0   | 1105.19  |
# |        Ind_Occ        | 18275 | float64 |   236   |  1.291   |  0.0  |   0.0   | 1366.579 |
# |       Tax_Income      | 18275 | float64 |    18   |  0.098   |  0.0  |  96.734 | 1055.947 |
# |      Age * Work%      | 18275 | float64 |   1079  |  5.904   |  0.0  |   0.0   |   90.0   |
# |       log Gains       | 18275 | float64 |   106   |   0.58   |  0.0  |   0.0   |  11.513  |
# |       log Losses      | 18275 | float64 |    86   |  0.471   |  0.0  |   0.0   |   8.38   |
# |     log Dividends     | 18275 | float64 |   420   |  2.298   |  0.0  |   0.0   |  10.714  |
# +-----------------------+-------+---------+---------+----------+-------+---------+----------+

# %%
def objective(trial):
    params = {
        "iterations": 1000,
        "depth": trial.suggest_int("depth", 4, 15),
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 1.0),
        "random_strength": trial.suggest_float("random_strength", 1e-3, 1e-1, log=True),
        "border_count": trial.suggest_int("border_count", 1, 255),
        "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1e-3, 1e2, log=True),
        "leaf_estimation_iterations": trial.suggest_int("leaf_estimation_iterations", 1, 10),
        "leaf_estimation_method": trial.suggest_categorical("leaf_estimation_method", ["Newton", "Gradient"]),
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
        "grow_policy": trial.suggest_categorical("grow_policy", ["SymmetricTree", "Depthwise", "Lossguide"]),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 100),
        "one_hot_max_size": trial.suggest_int("one_hot_max_size", 0, 25),
        "random_state": 42,
        "verbose": 0,
        "loss_function": "RMSE",
    }
    
    model = make_pipeline(
        CatBoostRegressor(**params)
        )
    
    val_scores, _ = cross_val_model(train, model, verbose=False)
    return np.mean(val_scores)

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=1000)
# Out:
# [I 2024-03-25 12:14:58,237] A new study created in memory with name: no-name-22ec796e-f183-4d5a-9fb9-2f3b39469b4f
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:15:44,318] Trial 0 finished with value: 749.2023205215067 and parameters: {'depth': 11, 'learning_rate': 0.2934711751074452, 'random_strength': 0.029678479637057248, 'border_count': 4, 'l2_leaf_reg': 0.03413815767777287, 'leaf_estimation_iterations': 5, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'Depthwise', 'min_data_in_leaf': 68, 'one_hot_max_size': 20}. Best is trial 0 with value: 749.2023205215067.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:18:19,249] Trial 1 finished with value: 681.9746408299823 and parameters: {'depth': 12, 'learning_rate': 0.24332893811159642, 'random_strength': 0.0017385260708588863, 'border_count': 124, 'l2_leaf_reg': 1.5845694208815264, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 30, 'one_hot_max_size': 5}. Best is trial 1 with value: 681.9746408299823.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:19:02,352] Trial 2 finished with value: 799.4692154684233 and parameters: {'depth': 6, 'learning_rate': 0.8704920605834501, 'random_strength': 0.00478155661781227, 'border_count': 203, 'l2_leaf_reg': 5.119888855387097, 'leaf_estimation_iterations': 9, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Depthwise', 'min_data_in_leaf': 8, 'one_hot_max_size': 17}. Best is trial 1 with value: 681.9746408299823.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:19:41,693] Trial 3 finished with value: 733.5070734566028 and parameters: {'depth': 13, 'learning_rate': 0.4701279489964623, 'random_strength': 0.018183638648719684, 'border_count': 210, 'l2_leaf_reg': 0.10869526639959284, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bayesian', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 36, 'one_hot_max_size': 19}. Best is trial 1 with value: 681.9746408299823.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:23:11,416] Trial 4 finished with value: 743.1388370466128 and parameters: {'depth': 12, 'learning_rate': 0.7179248764002446, 'random_strength': 0.013523274193199576, 'border_count': 113, 'l2_leaf_reg': 55.706502835713664, 'leaf_estimation_iterations': 10, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'Bayesian', 'grow_policy': 'Depthwise', 'min_data_in_leaf': 13, 'one_hot_max_size': 8}. Best is trial 1 with value: 681.9746408299823.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:28:16,945] Trial 5 finished with value: 683.7924963154652 and parameters: {'depth': 12, 'learning_rate': 0.2290191214390812, 'random_strength': 0.06571089358193383, 'border_count': 178, 'l2_leaf_reg': 0.7635214447647924, 'leaf_estimation_iterations': 7, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 15, 'one_hot_max_size': 14}. Best is trial 1 with value: 681.9746408299823.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:28:54,352] Trial 6 finished with value: 633.2294155844756 and parameters: {'depth': 8, 'learning_rate': 0.034002198077191674, 'random_strength': 0.0013078081815161827, 'border_count': 35, 'l2_leaf_reg': 1.572253337624325, 'leaf_estimation_iterations': 6, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'Bayesian', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 13, 'one_hot_max_size': 15}. Best is trial 6 with value: 633.2294155844756.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:30:05,695] Trial 7 finished with value: 754.1492245589791 and parameters: {'depth': 15, 'learning_rate': 0.40252064764373513, 'random_strength': 0.030115056067882062, 'border_count': 30, 'l2_leaf_reg': 0.07991631360940499, 'leaf_estimation_iterations': 5, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'MVS', 'grow_policy': 'Depthwise', 'min_data_in_leaf': 82, 'one_hot_max_size': 8}. Best is trial 6 with value: 633.2294155844756.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:30:52,497] Trial 8 finished with value: 638.4758137801899 and parameters: {'depth': 14, 'learning_rate': 0.049051045391140864, 'random_strength': 0.055250650876259244, 'border_count': 132, 'l2_leaf_reg': 3.9050023066687944, 'leaf_estimation_iterations': 10, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bayesian', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 47, 'one_hot_max_size': 13}. Best is trial 6 with value: 633.2294155844756.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:31:27,831] Trial 9 finished with value: 691.5763502851054 and parameters: {'depth': 6, 'learning_rate': 0.22762695602883398, 'random_strength': 0.014242045980288736, 'border_count': 226, 'l2_leaf_reg': 0.007948869656424912, 'leaf_estimation_iterations': 9, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 21, 'one_hot_max_size': 1}. Best is trial 6 with value: 633.2294155844756.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:32:00,349] Trial 10 finished with value: 630.3168636640982 and parameters: {'depth': 8, 'learning_rate': 0.03135658626539297, 'random_strength': 0.001103823938264955, 'border_count': 58, 'l2_leaf_reg': 0.0014346536752018054, 'leaf_estimation_iterations': 3, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 98, 'one_hot_max_size': 25}. Best is trial 10 with value: 630.3168636640982.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:32:31,851] Trial 11 finished with value: 616.8924647164782 and parameters: {'depth': 8, 'learning_rate': 0.009398287411595714, 'random_strength': 0.0010159991990480698, 'border_count': 60, 'l2_leaf_reg': 0.0012282518373817582, 'leaf_estimation_iterations': 3, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 100, 'one_hot_max_size': 24}. Best is trial 11 with value: 616.8924647164782.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:33:04,990] Trial 12 finished with value: 632.1666897771122 and parameters: {'depth': 9, 'learning_rate': 0.03623675963984535, 'random_strength': 0.003126689791785441, 'border_count': 64, 'l2_leaf_reg': 0.0019977374068259513, 'leaf_estimation_iterations': 3, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 99, 'one_hot_max_size': 25}. Best is trial 11 with value: 616.8924647164782.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:33:23,943] Trial 13 finished with value: 707.8715811470748 and parameters: {'depth': 4, 'learning_rate': 0.6427339803547711, 'random_strength': 0.0010688633768934314, 'border_count': 81, 'l2_leaf_reg': 0.0010233819662672382, 'leaf_estimation_iterations': 3, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 98, 'one_hot_max_size': 25}. Best is trial 11 with value: 616.8924647164782.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:33:56,029] Trial 14 finished with value: 669.5263285157992 and parameters: {'depth': 7, 'learning_rate': 0.14401887429143778, 'random_strength': 0.003939858115396512, 'border_count': 79, 'l2_leaf_reg': 0.008402998089980398, 'leaf_estimation_iterations': 3, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 76, 'one_hot_max_size': 22}. Best is trial 11 with value: 616.8924647164782.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:34:29,399] Trial 15 finished with value: 813.6706374131666 and parameters: {'depth': 10, 'learning_rate': 0.9853531029106741, 'random_strength': 0.002258563076069716, 'border_count': 51, 'l2_leaf_reg': 0.006491661976280965, 'leaf_estimation_iterations': 4, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 86, 'one_hot_max_size': 22}. Best is trial 11 with value: 616.8924647164782.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:34:37,569] Trial 16 finished with value: 662.7313233627904 and parameters: {'depth': 4, 'learning_rate': 0.363719511802187, 'random_strength': 0.006552574087430183, 'border_count': 3, 'l2_leaf_reg': 0.00313185639451462, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 73, 'one_hot_max_size': 25}. Best is trial 11 with value: 616.8924647164782.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:35:11,607] Trial 17 finished with value: 665.7258189363522 and parameters: {'depth': 9, 'learning_rate': 0.1282043007165758, 'random_strength': 0.002225278541413144, 'border_count': 101, 'l2_leaf_reg': 0.02842357547000859, 'leaf_estimation_iterations': 4, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 58, 'one_hot_max_size': 21}. Best is trial 11 with value: 616.8924647164782.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:35:42,711] Trial 18 finished with value: 689.7160318179042 and parameters: {'depth': 7, 'learning_rate': 0.5666485821970161, 'random_strength': 0.0010104802456816439, 'border_count': 158, 'l2_leaf_reg': 98.47470709923375, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 91, 'one_hot_max_size': 17}. Best is trial 11 with value: 616.8924647164782.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:37:07,485] Trial 19 finished with value: 674.5169504511249 and parameters: {'depth': 10, 'learning_rate': 0.14228711575669262, 'random_strength': 0.008047985386196357, 'border_count': 250, 'l2_leaf_reg': 0.0010422936650325112, 'leaf_estimation_iterations': 7, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 61, 'one_hot_max_size': 10}. Best is trial 11 with value: 616.8924647164782.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:37:42,285] Trial 20 finished with value: 710.7951066977217 and parameters: {'depth': 8, 'learning_rate': 0.33069678021843146, 'random_strength': 0.0016345805476207771, 'border_count': 93, 'l2_leaf_reg': 0.02595156284903684, 'leaf_estimation_iterations': 4, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 93, 'one_hot_max_size': 23}. Best is trial 11 with value: 616.8924647164782.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:38:14,516] Trial 21 finished with value: 614.1625910026885 and parameters: {'depth': 9, 'learning_rate': 0.0033162009487981217, 'random_strength': 0.0034560680760736535, 'border_count': 60, 'l2_leaf_reg': 0.002361204207465545, 'leaf_estimation_iterations': 3, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 100, 'one_hot_max_size': 25}. Best is trial 21 with value: 614.1625910026885.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:38:45,770] Trial 22 finished with value: 613.972280268846 and parameters: {'depth': 8, 'learning_rate': 0.0033554029100809966, 'random_strength': 0.002821161334591179, 'border_count': 46, 'l2_leaf_reg': 0.0031410394120325023, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 100, 'one_hot_max_size': 18}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:39:10,385] Trial 23 finished with value: 657.2572999864395 and parameters: {'depth': 6, 'learning_rate': 0.1219351435913554, 'random_strength': 0.002890186538920159, 'border_count': 27, 'l2_leaf_reg': 0.004512466152430498, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 82, 'one_hot_max_size': 18}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:39:39,043] Trial 24 finished with value: 614.2064133771108 and parameters: {'depth': 10, 'learning_rate': 0.003454725708398939, 'random_strength': 0.005020779227963261, 'border_count': 68, 'l2_leaf_reg': 0.014135003842671374, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 88, 'one_hot_max_size': 23}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:40:08,642] Trial 25 finished with value: 679.1327766007684 and parameters: {'depth': 11, 'learning_rate': 0.17796379272046123, 'random_strength': 0.004748252450420121, 'border_count': 149, 'l2_leaf_reg': 0.013435072441862246, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 88, 'one_hot_max_size': 21}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:40:38,266] Trial 26 finished with value: 652.867716685379 and parameters: {'depth': 10, 'learning_rate': 0.08650372892372594, 'random_strength': 0.006540169169599244, 'border_count': 43, 'l2_leaf_reg': 0.17662433677559092, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 78, 'one_hot_max_size': 16}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:41:08,665] Trial 27 finished with value: 614.680727019685 and parameters: {'depth': 11, 'learning_rate': 0.003986013201936356, 'random_strength': 0.009122697585569606, 'border_count': 75, 'l2_leaf_reg': 0.003363729106742445, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 67, 'one_hot_max_size': 20}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:41:49,295] Trial 28 finished with value: 711.4736704827127 and parameters: {'depth': 9, 'learning_rate': 0.21492776849218215, 'random_strength': 0.0039432162495070065, 'border_count': 18, 'l2_leaf_reg': 0.017674847772392015, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bayesian', 'grow_policy': 'Depthwise', 'min_data_in_leaf': 91, 'one_hot_max_size': 23}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:42:06,747] Trial 29 finished with value: 692.1955252682465 and parameters: {'depth': 7, 'learning_rate': 0.26809880109024464, 'random_strength': 0.0026909938176955506, 'border_count': 11, 'l2_leaf_reg': 0.0521693074874846, 'leaf_estimation_iterations': 5, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 68, 'one_hot_max_size': 20}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:42:28,083] Trial 30 finished with value: 713.7874809281228 and parameters: {'depth': 5, 'learning_rate': 0.417212561992246, 'random_strength': 0.005948210746755514, 'border_count': 89, 'l2_leaf_reg': 0.3689171640808997, 'leaf_estimation_iterations': 4, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'MVS', 'grow_policy': 'Depthwise', 'min_data_in_leaf': 49, 'one_hot_max_size': 18}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:42:56,485] Trial 31 finished with value: 652.3053497060524 and parameters: {'depth': 11, 'learning_rate': 0.08675113277002366, 'random_strength': 0.009841088452233695, 'border_count': 71, 'l2_leaf_reg': 0.003031555518850549, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 64, 'one_hot_max_size': 20}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:43:24,789] Trial 32 finished with value: 657.3647361306264 and parameters: {'depth': 11, 'learning_rate': 0.09469171913596161, 'random_strength': 0.01002423233676676, 'border_count': 109, 'l2_leaf_reg': 0.0031705667919985545, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 83, 'one_hot_max_size': 23}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:43:50,131] Trial 33 finished with value: 614.8220241062567 and parameters: {'depth': 10, 'learning_rate': 0.002740710657821707, 'random_strength': 0.003554784875154795, 'border_count': 48, 'l2_leaf_reg': 0.011846800226646838, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 72, 'one_hot_max_size': 19}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:44:18,355] Trial 34 finished with value: 677.3780288817832 and parameters: {'depth': 13, 'learning_rate': 0.16464397982305412, 'random_strength': 0.025866328438640503, 'border_count': 129, 'l2_leaf_reg': 0.00412332025422954, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 56, 'one_hot_max_size': 11}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:44:43,648] Trial 35 finished with value: 700.2921716349268 and parameters: {'depth': 9, 'learning_rate': 0.2848484532472411, 'random_strength': 0.004984861521038504, 'border_count': 72, 'l2_leaf_reg': 0.04054982681619705, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 93, 'one_hot_max_size': 22}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:45:39,162] Trial 36 finished with value: 659.3781269226095 and parameters: {'depth': 11, 'learning_rate': 0.08086385394723232, 'random_strength': 0.001742274472492456, 'border_count': 43, 'l2_leaf_reg': 0.006733157321418054, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 39, 'one_hot_max_size': 19}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:46:53,193] Trial 37 finished with value: 803.3419763091522 and parameters: {'depth': 12, 'learning_rate': 0.7213874712709798, 'random_strength': 0.009636077067879546, 'border_count': 115, 'l2_leaf_reg': 0.0022218930530793287, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bayesian', 'grow_policy': 'Depthwise', 'min_data_in_leaf': 78, 'one_hot_max_size': 16}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:47:14,350] Trial 38 finished with value: 680.7521075424539 and parameters: {'depth': 12, 'learning_rate': 0.18835486525102982, 'random_strength': 0.015594861690309313, 'border_count': 24, 'l2_leaf_reg': 0.01844104697298053, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 3, 'one_hot_max_size': 21}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:47:50,063] Trial 39 finished with value: 645.5506282945802 and parameters: {'depth': 13, 'learning_rate': 0.0683975235791169, 'random_strength': 0.022595886205690502, 'border_count': 95, 'l2_leaf_reg': 0.108582614210809, 'leaf_estimation_iterations': 6, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bayesian', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 68, 'one_hot_max_size': 4}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:48:16,673] Trial 40 finished with value: 734.8366964747095 and parameters: {'depth': 8, 'learning_rate': 0.49264932748202983, 'random_strength': 0.03904905228754199, 'border_count': 36, 'l2_leaf_reg': 21.717832381338038, 'leaf_estimation_iterations': 3, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'MVS', 'grow_policy': 'Depthwise', 'min_data_in_leaf': 86, 'one_hot_max_size': 13}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:48:42,396] Trial 41 finished with value: 615.5567983940463 and parameters: {'depth': 10, 'learning_rate': 0.006411626013393901, 'random_strength': 0.004321079418961506, 'border_count': 50, 'l2_leaf_reg': 0.007661275143511961, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 74, 'one_hot_max_size': 19}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:49:11,834] Trial 42 finished with value: 619.7051035855932 and parameters: {'depth': 10, 'learning_rate': 0.0123604620805934, 'random_strength': 0.003419444553073701, 'border_count': 69, 'l2_leaf_reg': 0.011814894168677493, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 94, 'one_hot_max_size': 17}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:49:35,880] Trial 43 finished with value: 643.6581671298298 and parameters: {'depth': 11, 'learning_rate': 0.06391974512184284, 'random_strength': 0.002048332451388536, 'border_count': 53, 'l2_leaf_reg': 0.0018173923430826028, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 54, 'one_hot_max_size': 15}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:50:02,473] Trial 44 finished with value: 621.2043425656611 and parameters: {'depth': 9, 'learning_rate': 0.014589716412918587, 'random_strength': 0.0053985766761746184, 'border_count': 81, 'l2_leaf_reg': 0.0049975713555870434, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 70, 'one_hot_max_size': 23}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:50:30,258] Trial 45 finished with value: 618.0887994415054 and parameters: {'depth': 10, 'learning_rate': 0.0018168234283809854, 'random_strength': 0.003416886661370055, 'border_count': 44, 'l2_leaf_reg': 0.009644138033818144, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 100, 'one_hot_max_size': 24}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:50:55,844] Trial 46 finished with value: 658.0194775240212 and parameters: {'depth': 8, 'learning_rate': 0.10843336115838759, 'random_strength': 0.0074294439372588955, 'border_count': 16, 'l2_leaf_reg': 0.002107864265885979, 'leaf_estimation_iterations': 3, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 80, 'one_hot_max_size': 20}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:51:19,884] Trial 47 finished with value: 641.9403061534068 and parameters: {'depth': 14, 'learning_rate': 0.056876709628280765, 'random_strength': 0.012048539284347895, 'border_count': 61, 'l2_leaf_reg': 0.019374356181005227, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 44, 'one_hot_max_size': 19}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:52:03,276] Trial 48 finished with value: 691.8038981877087 and parameters: {'depth': 9, 'learning_rate': 0.21002797785995841, 'random_strength': 0.002568300052946402, 'border_count': 31, 'l2_leaf_reg': 1.848030394717724, 'leaf_estimation_iterations': 9, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bayesian', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 25, 'one_hot_max_size': 24}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:52:30,834] Trial 49 finished with value: 682.019980350696 and parameters: {'depth': 7, 'learning_rate': 0.1590374395560275, 'random_strength': 0.09051695797963598, 'border_count': 82, 'l2_leaf_reg': 0.05942244359203787, 'leaf_estimation_iterations': 3, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 96, 'one_hot_max_size': 18}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:53:00,860] Trial 50 finished with value: 640.5878744895329 and parameters: {'depth': 11, 'learning_rate': 0.05267078041230149, 'random_strength': 0.0013812435252699923, 'border_count': 142, 'l2_leaf_reg': 0.0016119915359552501, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 88, 'one_hot_max_size': 22}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:53:25,998] Trial 51 finished with value: 614.5030613197086 and parameters: {'depth': 10, 'learning_rate': 0.004260816172504696, 'random_strength': 0.004682447371931225, 'border_count': 52, 'l2_leaf_reg': 0.006153608155197203, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 74, 'one_hot_max_size': 20}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:53:49,642] Trial 52 finished with value: 637.8390546923831 and parameters: {'depth': 12, 'learning_rate': 0.043503464869600245, 'random_strength': 0.0037251346565635303, 'border_count': 62, 'l2_leaf_reg': 0.004682911087405216, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 62, 'one_hot_max_size': 21}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:54:16,303] Trial 53 finished with value: 661.1407796571223 and parameters: {'depth': 10, 'learning_rate': 0.11816597945957705, 'random_strength': 0.008317900546706123, 'border_count': 56, 'l2_leaf_reg': 0.002992497570225535, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 84, 'one_hot_max_size': 20}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:54:40,791] Trial 54 finished with value: 617.6651853259548 and parameters: {'depth': 9, 'learning_rate': 0.0018589038143956315, 'random_strength': 0.005490228783364432, 'border_count': 34, 'l2_leaf_reg': 0.012192057354950334, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 73, 'one_hot_max_size': 24}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:55:10,603] Trial 55 finished with value: 634.7578418094374 and parameters: {'depth': 12, 'learning_rate': 0.04077962964612121, 'random_strength': 0.004397514341510892, 'border_count': 73, 'l2_leaf_reg': 0.006463640124591691, 'leaf_estimation_iterations': 3, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 89, 'one_hot_max_size': 17}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:55:39,152] Trial 56 finished with value: 663.6628513624489 and parameters: {'depth': 8, 'learning_rate': 0.116640766349373, 'random_strength': 0.002992995897910497, 'border_count': 178, 'l2_leaf_reg': 0.03228567909253291, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 96, 'one_hot_max_size': 14}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:56:11,802] Trial 57 finished with value: 639.9765337214742 and parameters: {'depth': 10, 'learning_rate': 0.05030942058792564, 'random_strength': 0.002027552524286102, 'border_count': 102, 'l2_leaf_reg': 0.0010329174498050326, 'leaf_estimation_iterations': 8, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 79, 'one_hot_max_size': 25}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:56:35,139] Trial 58 finished with value: 760.3056012100202 and parameters: {'depth': 11, 'learning_rate': 0.7473690514090265, 'random_strength': 0.0024270845044097483, 'border_count': 42, 'l2_leaf_reg': 0.20549398129243387, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 72, 'one_hot_max_size': 22}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:57:14,955] Trial 59 finished with value: 743.6742730492062 and parameters: {'depth': 9, 'learning_rate': 0.5412207549526621, 'random_strength': 0.006620011417385422, 'border_count': 86, 'l2_leaf_reg': 12.276576078133816, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Depthwise', 'min_data_in_leaf': 65, 'one_hot_max_size': 0}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:57:34,198] Trial 60 finished with value: 852.330311189967 and parameters: {'depth': 8, 'learning_rate': 0.979184066077819, 'random_strength': 0.003264742022958174, 'border_count': 4, 'l2_leaf_reg': 0.0023439143255338303, 'leaf_estimation_iterations': 6, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 96, 'one_hot_max_size': 16}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:57:59,106] Trial 61 finished with value: 628.3111072111894 and parameters: {'depth': 10, 'learning_rate': 0.025517261582241005, 'random_strength': 0.004385048217236903, 'border_count': 54, 'l2_leaf_reg': 0.0083701348642121, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 59, 'one_hot_max_size': 19}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:58:24,652] Trial 62 finished with value: 614.9022497647959 and parameters: {'depth': 10, 'learning_rate': 0.002755823293690153, 'random_strength': 0.004160356276629835, 'border_count': 52, 'l2_leaf_reg': 0.005304037712878022, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 76, 'one_hot_max_size': 18}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:58:49,515] Trial 63 finished with value: 651.0555898778973 and parameters: {'depth': 10, 'learning_rate': 0.08116662595686064, 'random_strength': 0.003750425628795759, 'border_count': 65, 'l2_leaf_reg': 0.004219263940492393, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 76, 'one_hot_max_size': 18}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:59:15,145] Trial 64 finished with value: 667.4459309005726 and parameters: {'depth': 9, 'learning_rate': 0.13971549717080936, 'random_strength': 0.006195897725710963, 'border_count': 24, 'l2_leaf_reg': 0.0199465726384334, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 66, 'one_hot_max_size': 21}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 12:59:38,960] Trial 65 finished with value: 655.1605996718625 and parameters: {'depth': 11, 'learning_rate': 0.0952978837213656, 'random_strength': 0.0050535830180917785, 'border_count': 46, 'l2_leaf_reg': 0.0014407860419117678, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 85, 'one_hot_max_size': 23}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 13:00:10,405] Trial 66 finished with value: 620.9281820263799 and parameters: {'depth': 9, 'learning_rate': 0.0015497050155240605, 'random_strength': 0.0027515288406594115, 'border_count': 77, 'l2_leaf_reg': 0.0030822049854797697, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bayesian', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 89, 'one_hot_max_size': 15}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 13:00:40,254] Trial 67 finished with value: 639.4970799621195 and parameters: {'depth': 10, 'learning_rate': 0.03610839717040343, 'random_strength': 0.007895880657661239, 'border_count': 38, 'l2_leaf_reg': 0.005930901254789195, 'leaf_estimation_iterations': 4, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'MVS', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 80, 'one_hot_max_size': 20}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 13:01:02,895] Trial 68 finished with value: 684.0396368886179 and parameters: {'depth': 8, 'learning_rate': 0.24122666174351468, 'random_strength': 0.011073122841695475, 'border_count': 14, 'l2_leaf_reg': 0.012637036038608059, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 92, 'one_hot_max_size': 11}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 13:01:28,543] Trial 69 finished with value: 676.2293112693937 and parameters: {'depth': 7, 'learning_rate': 0.184981467549892, 'random_strength': 0.004007089433587616, 'border_count': 67, 'l2_leaf_reg': 0.0032568513872949833, 'leaf_estimation_iterations': 2, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Lossguide', 'min_data_in_leaf': 100, 'one_hot_max_size': 18}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-25 13:02:20,511] Trial 70 finished with value: 805.3403641944388 and parameters: {'depth': 11, 'learning_rate': 0.7875964534494966, 'random_strength': 0.0018412738795496153, 'border_count': 100, 'l2_leaf_reg': 0.024552146094320663, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Gradient', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'Depthwise', 'min_data_in_leaf': 70, 'one_hot_max_size': 21}. Best is trial 22 with value: 613.972280268846.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# ...
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:36:05,581] Trial 976 finished with value: 613.8774152554241 and parameters: {'depth': 11, 'learning_rate': 0.030056925132246642, 'random_strength': 0.05190077508747075, 'border_count': 33, 'l2_leaf_reg': 81.52254404171242, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 19, 'one_hot_max_size': 24}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:36:33,953] Trial 977 finished with value: 639.1781597175878 and parameters: {'depth': 11, 'learning_rate': 0.0010361369265482236, 'random_strength': 0.08150802555409921, 'border_count': 32, 'l2_leaf_reg': 99.1315085714995, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 21, 'one_hot_max_size': 24}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:37:01,976] Trial 978 finished with value: 615.1786325955842 and parameters: {'depth': 11, 'learning_rate': 0.04766552147140088, 'random_strength': 0.08849783191541143, 'border_count': 37, 'l2_leaf_reg': 68.19402226766123, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 16, 'one_hot_max_size': 25}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:37:28,427] Trial 979 finished with value: 613.7079430827695 and parameters: {'depth': 11, 'learning_rate': 0.019149511700156878, 'random_strength': 0.09147178220226386, 'border_count': 29, 'l2_leaf_reg': 47.5827201770078, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 21, 'one_hot_max_size': 24}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:37:54,388] Trial 980 finished with value: 615.9117932929694 and parameters: {'depth': 11, 'learning_rate': 0.06740793190996994, 'random_strength': 0.07101167922451694, 'border_count': 38, 'l2_leaf_reg': 99.94217551269216, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 23, 'one_hot_max_size': 25}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:38:20,900] Trial 981 finished with value: 613.8003971874775 and parameters: {'depth': 11, 'learning_rate': 0.031805307458470516, 'random_strength': 0.09922460713634479, 'border_count': 31, 'l2_leaf_reg': 79.47548533710346, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 15, 'one_hot_max_size': 24}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:38:46,622] Trial 982 finished with value: 613.5582726060163 and parameters: {'depth': 11, 'learning_rate': 0.01595110249132882, 'random_strength': 0.0804107724685394, 'border_count': 26, 'l2_leaf_reg': 60.310877689316975, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 25, 'one_hot_max_size': 25}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:39:11,232] Trial 983 finished with value: 614.7834603959358 and parameters: {'depth': 11, 'learning_rate': 0.04739334478912584, 'random_strength': 0.07732168326509099, 'border_count': 33, 'l2_leaf_reg': 67.71779759654585, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 18, 'one_hot_max_size': 24}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:39:36,829] Trial 984 finished with value: 613.5205258402596 and parameters: {'depth': 11, 'learning_rate': 0.017795364498494094, 'random_strength': 0.06396802272610969, 'border_count': 25, 'l2_leaf_reg': 79.37668231775133, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 20, 'one_hot_max_size': 25}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:40:01,038] Trial 985 finished with value: 618.3967148268755 and parameters: {'depth': 11, 'learning_rate': 0.06908548169844489, 'random_strength': 0.0870783880015979, 'border_count': 29, 'l2_leaf_reg': 50.01415085775551, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 22, 'one_hot_max_size': 24}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:40:25,758] Trial 986 finished with value: 614.3333109297654 and parameters: {'depth': 11, 'learning_rate': 0.038314675802677584, 'random_strength': 0.0994312833559873, 'border_count': 24, 'l2_leaf_reg': 80.66686639684943, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 18, 'one_hot_max_size': 25}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:40:54,101] Trial 987 finished with value: 614.5006026382592 and parameters: {'depth': 11, 'learning_rate': 0.03478544446210538, 'random_strength': 0.07141091251139647, 'border_count': 36, 'l2_leaf_reg': 59.82342236438929, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 15, 'one_hot_max_size': 24}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:41:22,037] Trial 988 finished with value: 623.7630528614175 and parameters: {'depth': 11, 'learning_rate': 0.0018645612216632267, 'random_strength': 0.08823808601005692, 'border_count': 30, 'l2_leaf_reg': 99.94926814430121, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 19, 'one_hot_max_size': 24}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:41:42,600] Trial 989 finished with value: 616.9852918662751 and parameters: {'depth': 11, 'learning_rate': 0.08669522407426042, 'random_strength': 0.07759155004285459, 'border_count': 23, 'l2_leaf_reg': 68.68293507830296, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 21, 'one_hot_max_size': 25}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:42:10,836] Trial 990 finished with value: 618.2640991726901 and parameters: {'depth': 11, 'learning_rate': 0.05972160079932396, 'random_strength': 0.08533850933731717, 'border_count': 38, 'l2_leaf_reg': 44.873985206483766, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 17, 'one_hot_max_size': 24}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:42:36,384] Trial 991 finished with value: 613.5256775580795 and parameters: {'depth': 11, 'learning_rate': 0.020137893887678858, 'random_strength': 0.06801204103778215, 'border_count': 24, 'l2_leaf_reg': 76.87849207680286, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 15, 'one_hot_max_size': 25}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:43:03,565] Trial 992 finished with value: 614.4815753430654 and parameters: {'depth': 11, 'learning_rate': 0.0444358989854215, 'random_strength': 0.0919084593264076, 'border_count': 29, 'l2_leaf_reg': 82.0586041422484, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 20, 'one_hot_max_size': 24}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:43:28,804] Trial 993 finished with value: 613.6843980372375 and parameters: {'depth': 11, 'learning_rate': 0.01789942749896518, 'random_strength': 0.08130913311044402, 'border_count': 24, 'l2_leaf_reg': 55.52655237399236, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 25, 'one_hot_max_size': 25}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:43:55,537] Trial 994 finished with value: 614.2011714638013 and parameters: {'depth': 11, 'learning_rate': 0.03418643217091688, 'random_strength': 0.07463153046282758, 'border_count': 34, 'l2_leaf_reg': 80.6228886911582, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 23, 'one_hot_max_size': 24}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:44:20,126] Trial 995 finished with value: 613.1850866291846 and parameters: {'depth': 11, 'learning_rate': 0.018077672003749243, 'random_strength': 0.06362821898758432, 'border_count': 22, 'l2_leaf_reg': 99.22568050413288, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 18, 'one_hot_max_size': 24}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:44:47,962] Trial 996 finished with value: 620.0107579353627 and parameters: {'depth': 11, 'learning_rate': 0.0023260560190933102, 'random_strength': 0.06208650140939441, 'border_count': 29, 'l2_leaf_reg': 97.67573511744227, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 17, 'one_hot_max_size': 25}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:45:14,817] Trial 997 finished with value: 648.4723803555984 and parameters: {'depth': 11, 'learning_rate': 0.3977726233194673, 'random_strength': 0.06040652212151306, 'border_count': 32, 'l2_leaf_reg': 83.36002194361721, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 19, 'one_hot_max_size': 25}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:45:38,322] Trial 998 finished with value: 615.32996482362 and parameters: {'depth': 11, 'learning_rate': 0.05780843428859027, 'random_strength': 0.06803481879490768, 'border_count': 23, 'l2_leaf_reg': 98.0688988855757, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 17, 'one_hot_max_size': 24}. Best is trial 569 with value: 612.9277776344513.
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [I 2024-03-26 00:46:09,507] Trial 999 finished with value: 613.8358657146048 and parameters: {'depth': 11, 'learning_rate': 0.017730443100860107, 'random_strength': 0.08057627702279506, 'border_count': 40, 'l2_leaf_reg': 99.9736836072482, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'MVS', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 15, 'one_hot_max_size': 25}. Best is trial 569 with value: 612.9277776344513.

# %%
best_params = study.best_params

best_params["random_state"] = 42
best_params["verbose"] = 0
best_params["iterations"] = 1000
best_params["loss_function"] = "RMSE"

CB = make_pipeline(
    CatBoostRegressor(**best_params)
    )

# %%
print(best_params)
# Out:
# {'depth': 9, 'learning_rate': 0.02028018999171634, 'random_strength': 0.005351695733421447, 'border_count': 52, 'l2_leaf_reg': 71.7354952340875, 'leaf_estimation_iterations': 1, 'leaf_estimation_method': 'Newton', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'min_data_in_leaf': 74, 'one_hot_max_size': 24, 'random_state': 42, 'verbose': 0, 'iterations': 1000, 'loss_function': 'RMSE'}

# %%
# Train Catboost Model
_, test_predictions = cross_val_model(train, CB)
# Out:
# /home/sts07142/.local/lib/python3.8/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# ----------------------------------------------------------------------------------------------------
# Fold: 0
# Train Accuracy Score:-578.5448349384064
# Valid Accuracy Score:-609.9067605819326
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Fold: 1
# Train Accuracy Score:-583.0801079852223
# Valid Accuracy Score:-595.8819691902593
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Fold: 2
# Train Accuracy Score:-574.8157792296184
# Valid Accuracy Score:-624.6634839292354
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Fold: 3
# Train Accuracy Score:-578.2583124543946
# Valid Accuracy Score:-610.5132056282071
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Fold: 4
# Train Accuracy Score:-578.3820280178892
# Valid Accuracy Score:-623.6734688426218
# ----------------------------------------------------------------------------------------------------
# RMSE Score: 612.9277776344513

# %%
submission = pd.read_csv('./sample_submission.csv')
submission['Income'] = test_predictions

# %%
submission.to_csv('./baseline_submission.csv', index=False)
