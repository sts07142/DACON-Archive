# %%
import pandas as pd
import numpy as np
import copy
import re
import random
import os
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split as tts
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
submission = pd.read_csv('sample_submission.csv')

# %%
#핫덱대체
#근로기간 Unknown <<< 나머지 학습해서 결과 뽑기?
"""
    근로기간
    10+ years    31585
    2 years       8450
    < 1 year      7774
    3 years       7581
    1 year        6249
    Unknown       5671 << 5.8% 정도
    5 years       5665
    4 years       5588
    8 years       4888
    6 years       3874
    7 years       3814
    9 years       3744
    10+years       896
    <1 year        370
    3               89
    1 years         56
"""

# %%
def only_int(string):
    num = re.sub(r'[^0-9]', '', string)
    if num:
        return num
    else:
        return "5"

def extract_categorical_columns(df):
    data = []
    for e, i in enumerate(df.columns):
        if df[i].dtypes == 'object':
            data.append(i)
    return data

def ordinal_encoding(train_df, test_df, categorical_columns):
    from sklearn.preprocessing import OrdinalEncoder
    train, test = train_df.copy(), test_df.copy()
    data = {}
    for col in categorical_columns:
        ordinal_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
        ordinal_encoder.fit(train[col].values.reshape(-1, 1))
        train[col] = ordinal_encoder.transform(train[col].values.reshape(-1, 1)).reshape(-1)
        if col in test:
            test[col] = ordinal_encoder.transform(test[col].values.reshape(-1, 1)).reshape(-1)
        data[col] = ordinal_encoder
    return train, test, data

def sep_ml_xy(df, target):
    y = df[target]
    x = df.drop(columns=target)
    return x, y

def ml_train_valid(model, metric, metric_options, train_data, train_target, test_data, test_target):
    model = model.fit(train_data, train_target)
    pred = model.predict(test_data)
    evaluate = metric(test_target, pred, **metric_options)
    return pred, evaluate, model

def ml_predict(model, test_data):
    pred = model.predict(test_data)
    return pred

# %%
train = train.drop(columns=['ID'])
test = test.drop(columns=['ID'])

for span in ["근로기간"]:
    train[span] = train[span].apply(lambda x: int(only_int(x)))
    test[span] = test[span].apply(lambda x: int(only_int(x)))

for span in ["대출기간"]:
    train[span] = train[span].apply(lambda x: int(int(only_int(x))/12))
    test[span] = test[span].apply(lambda x: int(int(only_int(x))/12))
    
for span in ["총상환이자", "총연체금액", "연체계좌수"]:
    train[span] = train[span].apply(lambda x: int(x))
    test[span] = test[span].apply(lambda x: int(x))
# display(train.head(3), test.head(3))

# %%
categorical_features = ['주택소유상태', '대출목적']

for i in categorical_features:
    le = LabelEncoder()
    le=le.fit(train[i]) 
    train[i]=le.transform(train[i])
    
    for case in np.unique(test[i]):
        if case not in le.classes_: 
            le.classes_ = np.append(le.classes_, case) 
    test[i]=le.transform(test[i])

# display(train.head(3), test.head(3))

# %%
# columns_to_scale = ['대출금액','연간소득', '부채_대비_소득_비율', '총상환원금', '총상환이자', '총연체금액']
# 대출금액, 대출기간, 근로기간, 주택소유상태, 연간소득, 부채_대비_소득_비율, 총계좌수, 대출목적, 최근_2년간_연체_횟수, 총상환원금, 총상환이자, 총연체금액, 연쳬계좌수

# 의미 있는 값 : 근로기간, 주택소유상태, 연간소득, 부채_대비_소득_비율, 대출목적, 최근_2년간_연체_횟수, 총상환원금, 총상환이자, 총연체금액
# 의미 없는 값 : 대출금액, 대출기간, 총계좌수, 연체계좌수, 
# 추가 하는 값 : 연체계좌수/총계좌수, 총상환원금+총상환이자-총연체금액/대출원금, 대출금액/대출기간/연간소득, 

# scaler = MinMaxScaler(feature_range=(0, 10))
# train[columns_to_scale] = scaler.fit_transform(train[columns_to_scale])
# test[columns_to_scale] = scaler.transform(test[columns_to_scale])

# Calculate additional values
train['연체계좌수/총계좌수'] = train['연체계좌수'] / train['총계좌수']
train['총상환원금+총상환이자-총연체금액/대출원금'] = (train['총상환원금'] + train['총상환이자'] - train['총연체금액']) / train['대출금액']

test['연체계좌수/총계좌수'] = test['연체계좌수'] / test['총계좌수']
test['총상환원금+총상환이자-총연체금액/대출원금'] = (test['총상환원금'] + test['총상환이자'] - test['총연체금액']) / test['대출금액']

columns_to_scale = ['연체계좌수/총계좌수', '총상환원금+총상환이자-총연체금액/대출원금']
scaler = MinMaxScaler(feature_range=(0, 10))
train[columns_to_scale] = scaler.fit_transform(train[columns_to_scale])
test[columns_to_scale] = scaler.transform(test[columns_to_scale])

# Remove meaningless values
# '대출금액', '대출기간', '총계좌수', '연체계좌수'

train = train.drop(columns=['최근_2년간_연체_횟수', '총계좌수'])
test = test.drop(columns=['최근_2년간_연체_횟수', '총계좌수'])

display(train.head(3), test.head(3))
# Out:
#        대출금액  대출기간  근로기간  주택소유상태       연간소득  부채_대비_소득_비율  대출목적   총상환원금   총상환이자  \
# 0  12480000     3     6       3   72000000        18.90     1       0       0
# 1  14400000     5    10       1  130800000        22.33    10  373572  234060
# 2  12000000     3     5       1   96000000         8.60     1  928644  151944
#
#    총연체금액  연체계좌수 대출등급  연체계좌수/총계좌수  총상환원금+총상환이자-총연체금액/대출원금
# 0      0      0    C         0.0                0.002985
# 1      0      0    B         0.0                0.406111
# 2      0      0    A         0.0                0.863269
#        대출금액  대출기간  근로기간  주택소유상태       연간소득  부채_대비_소득_비율  대출목적    총상환원금  \
# 0  16800000     3     8       1  132000000        19.64    10   394692
# 1   8400000     3     5       3   89971200        15.84     1        0
# 2  17280000     3     6       3  150000000         8.41     3  1786980
#
#     총상환이자  총연체금액  연체계좌수  연체계좌수/총계좌수  총상환원금+총상환이자-총연체금액/대출원금
# 0  146604      0      0         0.0                0.310799
# 1       0      0      0         0.0                0.002985
# 2  281820      0      0         0.0                1.146752

# %%
from sklearn.model_selection import GridSearchCV

categorical_columns = extract_categorical_columns(train)
train, test, ord_dict = ordinal_encoding(train, test, categorical_columns)
train_x, train_y = sep_ml_xy(train, "대출등급")
train_x, valid_x, train_y, valid_y = tts(train_x, train_y, train_size=0.8, shuffle=True, random_state=0)

model = XGBClassifier()
model = model.fit(train_x, train_y)

# %%
# # {'learning_rate': 0.1, 'max_depth': 10, 'reg_alpha': 0.01}
# params = {'max_depth':[8,9,10], 'reg_alpha':[0.08,0.010,0.12], 'learning_rate':[0.08, 0.09, 0.10]}
# gridcv = GridSearchCV(model, param_grid=params, cv=3)
# gridcv.fit(train_x, train_y, early_stopping_rounds=30, eval_metric='merror', eval_set=[(valid_x, valid_y)])
# print(gridcv.best_params_)

# %%
# model = XGBClassifier(n_estimators=1000, learning_rate=0.5, max_depth=12, reg_alpha=0.05)
model = XGBClassifier(n_estimators=1000, learning_rate=0.1, max_depth=10, reg_alpha=0.01)
model = model.fit(train_x, train_y, early_stopping_rounds=200, eval_metric='merror', eval_set=[(valid_x, valid_y)])
pred = model.predict(valid_x)
evaluate = f1_score(valid_y, pred, **{"average": "macro"})

#_, evaluate, model = ml_train_valid(model, f1_score, {"average": "macro"}, train_x, train_y, valid_x, valid_y)
# Out:
# [0]	validation_0-merror:0.19736
# [1]	validation_0-merror:0.19357
# [2]	validation_0-merror:0.19394
# [3]	validation_0-merror:0.19362
# [4]	validation_0-merror:0.19207
# /home/sts07142/.local/lib/python3.8/site-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# /home/sts07142/.local/lib/python3.8/site-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [5]	validation_0-merror:0.19129
# [6]	validation_0-merror:0.18864
# [7]	validation_0-merror:0.18589
# [8]	validation_0-merror:0.18568
# [9]	validation_0-merror:0.18480
# [10]	validation_0-merror:0.18423
# [11]	validation_0-merror:0.18334
# [12]	validation_0-merror:0.18241
# [13]	validation_0-merror:0.18246
# [14]	validation_0-merror:0.18220
# [15]	validation_0-merror:0.18116
# [16]	validation_0-merror:0.18002
# [17]	validation_0-merror:0.17877
# [18]	validation_0-merror:0.17753
# [19]	validation_0-merror:0.17623
# [20]	validation_0-merror:0.17488
# [21]	validation_0-merror:0.17275
# [22]	validation_0-merror:0.17166
# [23]	validation_0-merror:0.17098
# [24]	validation_0-merror:0.17057
# [25]	validation_0-merror:0.16953
# [26]	validation_0-merror:0.16854
# [27]	validation_0-merror:0.16735
# [28]	validation_0-merror:0.16668
# [29]	validation_0-merror:0.16610
# [30]	validation_0-merror:0.16522
# [31]	validation_0-merror:0.16429
# [32]	validation_0-merror:0.16377
# [33]	validation_0-merror:0.16263
# [34]	validation_0-merror:0.16133
# [35]	validation_0-merror:0.16096
# [36]	validation_0-merror:0.16029
# [37]	validation_0-merror:0.15946
# [38]	validation_0-merror:0.15904
# [39]	validation_0-merror:0.15774
# [40]	validation_0-merror:0.15764
# [41]	validation_0-merror:0.15795
# [42]	validation_0-merror:0.15712
# [43]	validation_0-merror:0.15619
# [44]	validation_0-merror:0.15572
# [45]	validation_0-merror:0.15572
# [46]	validation_0-merror:0.15494
# [47]	validation_0-merror:0.15406
# [48]	validation_0-merror:0.15318
# [49]	validation_0-merror:0.15229
# [50]	validation_0-merror:0.15177
# [51]	validation_0-merror:0.15125
# [52]	validation_0-merror:0.15099
# [53]	validation_0-merror:0.15063
# [54]	validation_0-merror:0.15001
# [55]	validation_0-merror:0.14980
# [56]	validation_0-merror:0.14949
# [57]	validation_0-merror:0.14907
# [58]	validation_0-merror:0.14897
# [59]	validation_0-merror:0.14845
# [60]	validation_0-merror:0.14829
# [61]	validation_0-merror:0.14710
# [62]	validation_0-merror:0.14700
# [63]	validation_0-merror:0.14643
# [64]	validation_0-merror:0.14627
# [65]	validation_0-merror:0.14601
# [66]	validation_0-merror:0.14554
# [67]	validation_0-merror:0.14554
# [68]	validation_0-merror:0.14523
# [69]	validation_0-merror:0.14487
# [70]	validation_0-merror:0.14471
# [71]	validation_0-merror:0.14487
# [72]	validation_0-merror:0.14445
# [73]	validation_0-merror:0.14378
# [74]	validation_0-merror:0.14357
# [75]	validation_0-merror:0.14336
# [76]	validation_0-merror:0.14331
# [77]	validation_0-merror:0.14336
# [78]	validation_0-merror:0.14347
# [79]	validation_0-merror:0.14274
# [80]	validation_0-merror:0.14237
# [81]	validation_0-merror:0.14227
# [82]	validation_0-merror:0.14217
# [83]	validation_0-merror:0.14258
# [84]	validation_0-merror:0.14263
# [85]	validation_0-merror:0.14243
# [86]	validation_0-merror:0.14201
# [87]	validation_0-merror:0.14222
# [88]	validation_0-merror:0.14160
# [89]	validation_0-merror:0.14139
# [90]	validation_0-merror:0.14160
# [91]	validation_0-merror:0.14113
# [92]	validation_0-merror:0.14149
# [93]	validation_0-merror:0.14154
# [94]	validation_0-merror:0.14102
# [95]	validation_0-merror:0.14056
# [96]	validation_0-merror:0.14056
# [97]	validation_0-merror:0.14009
# [98]	validation_0-merror:0.14004
# [99]	validation_0-merror:0.13957
# [100]	validation_0-merror:0.13967
# [101]	validation_0-merror:0.13910
# [102]	validation_0-merror:0.13910
# [103]	validation_0-merror:0.13910
# [104]	validation_0-merror:0.13884
# [105]	validation_0-merror:0.13884
# [106]	validation_0-merror:0.13848
# [107]	validation_0-merror:0.13838
# [108]	validation_0-merror:0.13843
# [109]	validation_0-merror:0.13781
# [110]	validation_0-merror:0.13744
# [111]	validation_0-merror:0.13749
# [112]	validation_0-merror:0.13734
# [113]	validation_0-merror:0.13729
# [114]	validation_0-merror:0.13739
# [115]	validation_0-merror:0.13723
# [116]	validation_0-merror:0.13708
# [117]	validation_0-merror:0.13729
# [118]	validation_0-merror:0.13734
# [119]	validation_0-merror:0.13682
# [120]	validation_0-merror:0.13640
# [121]	validation_0-merror:0.13651
# [122]	validation_0-merror:0.13646
# [123]	validation_0-merror:0.13651
# [124]	validation_0-merror:0.13630
# [125]	validation_0-merror:0.13651
# [126]	validation_0-merror:0.13640
# [127]	validation_0-merror:0.13604
# [128]	validation_0-merror:0.13594
# [129]	validation_0-merror:0.13578
# [130]	validation_0-merror:0.13557
# [131]	validation_0-merror:0.13573
# [132]	validation_0-merror:0.13578
# [133]	validation_0-merror:0.13562
# [134]	validation_0-merror:0.13542
# [135]	validation_0-merror:0.13531
# [136]	validation_0-merror:0.13542
# [137]	validation_0-merror:0.13495
# [138]	validation_0-merror:0.13479
# [139]	validation_0-merror:0.13459
# [140]	validation_0-merror:0.13443
# [141]	validation_0-merror:0.13412
# [142]	validation_0-merror:0.13370
# [143]	validation_0-merror:0.13350
# [144]	validation_0-merror:0.13318
# [145]	validation_0-merror:0.13298
# [146]	validation_0-merror:0.13298
# [147]	validation_0-merror:0.13282
# [148]	validation_0-merror:0.13256
# [149]	validation_0-merror:0.13220
# [150]	validation_0-merror:0.13235
# [151]	validation_0-merror:0.13220
# [152]	validation_0-merror:0.13220
# [153]	validation_0-merror:0.13235
# [154]	validation_0-merror:0.13225
# [155]	validation_0-merror:0.13168
# [156]	validation_0-merror:0.13157
# [157]	validation_0-merror:0.13137
# [158]	validation_0-merror:0.13137
# [159]	validation_0-merror:0.13137
# [160]	validation_0-merror:0.13163
# [161]	validation_0-merror:0.13142
# [162]	validation_0-merror:0.13147
# [163]	validation_0-merror:0.13126
# [164]	validation_0-merror:0.13100
# [165]	validation_0-merror:0.13106
# [166]	validation_0-merror:0.13074
# [167]	validation_0-merror:0.13017
# [168]	validation_0-merror:0.13002
# [169]	validation_0-merror:0.12965
# [170]	validation_0-merror:0.12971
# [171]	validation_0-merror:0.12981
# [172]	validation_0-merror:0.12997
# [173]	validation_0-merror:0.12960
# [174]	validation_0-merror:0.12939
# [175]	validation_0-merror:0.12960
# [176]	validation_0-merror:0.12976
# [177]	validation_0-merror:0.12965
# [178]	validation_0-merror:0.12955
# [179]	validation_0-merror:0.12929
# [180]	validation_0-merror:0.12955
# [181]	validation_0-merror:0.12950
# [182]	validation_0-merror:0.12965
# [183]	validation_0-merror:0.12950
# [184]	validation_0-merror:0.12965
# [185]	validation_0-merror:0.12939
# [186]	validation_0-merror:0.12945
# [187]	validation_0-merror:0.12955
# [188]	validation_0-merror:0.12960
# [189]	validation_0-merror:0.12945
# [190]	validation_0-merror:0.12955
# [191]	validation_0-merror:0.12939
# [192]	validation_0-merror:0.12934
# [193]	validation_0-merror:0.12950
# [194]	validation_0-merror:0.12924
# [195]	validation_0-merror:0.12945
# [196]	validation_0-merror:0.12965
# [197]	validation_0-merror:0.12929
# [198]	validation_0-merror:0.12913
# [199]	validation_0-merror:0.12934
# [200]	validation_0-merror:0.12924
# [201]	validation_0-merror:0.12934
# [202]	validation_0-merror:0.12913
# [203]	validation_0-merror:0.12903
# [204]	validation_0-merror:0.12908
# [205]	validation_0-merror:0.12913
# [206]	validation_0-merror:0.12898
# [207]	validation_0-merror:0.12919
# [208]	validation_0-merror:0.12893
# [209]	validation_0-merror:0.12887
# [210]	validation_0-merror:0.12898
# [211]	validation_0-merror:0.12882
# [212]	validation_0-merror:0.12872
# [213]	validation_0-merror:0.12882
# [214]	validation_0-merror:0.12862
# [215]	validation_0-merror:0.12867
# [216]	validation_0-merror:0.12862
# [217]	validation_0-merror:0.12867
# [218]	validation_0-merror:0.12856
# [219]	validation_0-merror:0.12877
# [220]	validation_0-merror:0.12882
# [221]	validation_0-merror:0.12830
# [222]	validation_0-merror:0.12887
# [223]	validation_0-merror:0.12877
# [224]	validation_0-merror:0.12846
# [225]	validation_0-merror:0.12846
# [226]	validation_0-merror:0.12846
# [227]	validation_0-merror:0.12825
# [228]	validation_0-merror:0.12830
# [229]	validation_0-merror:0.12825
# [230]	validation_0-merror:0.12830
# [231]	validation_0-merror:0.12820
# [232]	validation_0-merror:0.12820
# [233]	validation_0-merror:0.12846
# [234]	validation_0-merror:0.12851
# [235]	validation_0-merror:0.12851
# [236]	validation_0-merror:0.12862
# [237]	validation_0-merror:0.12851
# [238]	validation_0-merror:0.12862
# [239]	validation_0-merror:0.12856
# [240]	validation_0-merror:0.12830
# [241]	validation_0-merror:0.12846
# [242]	validation_0-merror:0.12841
# [243]	validation_0-merror:0.12841
# [244]	validation_0-merror:0.12856
# [245]	validation_0-merror:0.12877
# [246]	validation_0-merror:0.12867
# [247]	validation_0-merror:0.12851
# [248]	validation_0-merror:0.12856
# [249]	validation_0-merror:0.12862
# [250]	validation_0-merror:0.12836
# [251]	validation_0-merror:0.12830
# [252]	validation_0-merror:0.12841
# [253]	validation_0-merror:0.12820
# [254]	validation_0-merror:0.12846
# [255]	validation_0-merror:0.12851
# [256]	validation_0-merror:0.12830
# [257]	validation_0-merror:0.12836
# [258]	validation_0-merror:0.12830
# [259]	validation_0-merror:0.12830
# [260]	validation_0-merror:0.12830
# [261]	validation_0-merror:0.12815
# [262]	validation_0-merror:0.12804
# [263]	validation_0-merror:0.12784
# [264]	validation_0-merror:0.12794
# [265]	validation_0-merror:0.12789
# [266]	validation_0-merror:0.12784
# [267]	validation_0-merror:0.12810
# [268]	validation_0-merror:0.12815
# [269]	validation_0-merror:0.12810
# [270]	validation_0-merror:0.12773
# [271]	validation_0-merror:0.12784
# [272]	validation_0-merror:0.12773
# [273]	validation_0-merror:0.12778
# [274]	validation_0-merror:0.12763
# [275]	validation_0-merror:0.12758
# [276]	validation_0-merror:0.12768
# [277]	validation_0-merror:0.12784
# [278]	validation_0-merror:0.12778
# [279]	validation_0-merror:0.12784
# [280]	validation_0-merror:0.12752
# [281]	validation_0-merror:0.12763
# [282]	validation_0-merror:0.12768
# [283]	validation_0-merror:0.12763
# [284]	validation_0-merror:0.12742
# [285]	validation_0-merror:0.12742
# [286]	validation_0-merror:0.12742
# [287]	validation_0-merror:0.12732
# [288]	validation_0-merror:0.12742
# [289]	validation_0-merror:0.12727
# [290]	validation_0-merror:0.12737
# [291]	validation_0-merror:0.12737
# [292]	validation_0-merror:0.12727
# [293]	validation_0-merror:0.12742
# [294]	validation_0-merror:0.12747
# [295]	validation_0-merror:0.12742
# [296]	validation_0-merror:0.12752
# [297]	validation_0-merror:0.12747
# [298]	validation_0-merror:0.12768
# [299]	validation_0-merror:0.12778
# [300]	validation_0-merror:0.12763
# [301]	validation_0-merror:0.12737
# [302]	validation_0-merror:0.12721
# [303]	validation_0-merror:0.12727
# [304]	validation_0-merror:0.12721
# [305]	validation_0-merror:0.12711
# [306]	validation_0-merror:0.12690
# [307]	validation_0-merror:0.12675
# [308]	validation_0-merror:0.12659
# [309]	validation_0-merror:0.12649
# [310]	validation_0-merror:0.12623
# [311]	validation_0-merror:0.12623
# [312]	validation_0-merror:0.12654
# [313]	validation_0-merror:0.12643
# [314]	validation_0-merror:0.12628
# [315]	validation_0-merror:0.12633
# [316]	validation_0-merror:0.12623
# [317]	validation_0-merror:0.12623
# [318]	validation_0-merror:0.12633
# [319]	validation_0-merror:0.12623
# [320]	validation_0-merror:0.12623
# [321]	validation_0-merror:0.12617
# [322]	validation_0-merror:0.12649
# [323]	validation_0-merror:0.12649
# [324]	validation_0-merror:0.12633
# [325]	validation_0-merror:0.12628
# [326]	validation_0-merror:0.12602
# [327]	validation_0-merror:0.12617
# [328]	validation_0-merror:0.12592
# [329]	validation_0-merror:0.12592
# [330]	validation_0-merror:0.12602
# [331]	validation_0-merror:0.12602
# [332]	validation_0-merror:0.12607
# [333]	validation_0-merror:0.12607
# [334]	validation_0-merror:0.12617
# [335]	validation_0-merror:0.12607
# [336]	validation_0-merror:0.12623
# [337]	validation_0-merror:0.12633
# [338]	validation_0-merror:0.12628
# [339]	validation_0-merror:0.12633
# [340]	validation_0-merror:0.12654
# [341]	validation_0-merror:0.12628
# [342]	validation_0-merror:0.12612
# [343]	validation_0-merror:0.12607
# [344]	validation_0-merror:0.12617
# [345]	validation_0-merror:0.12597
# [346]	validation_0-merror:0.12597
# [347]	validation_0-merror:0.12576
# [348]	validation_0-merror:0.12592
# [349]	validation_0-merror:0.12607
# [350]	validation_0-merror:0.12560
# [351]	validation_0-merror:0.12576
# [352]	validation_0-merror:0.12581
# [353]	validation_0-merror:0.12555
# [354]	validation_0-merror:0.12550
# [355]	validation_0-merror:0.12545
# [356]	validation_0-merror:0.12560
# [357]	validation_0-merror:0.12560
# [358]	validation_0-merror:0.12555
# [359]	validation_0-merror:0.12555
# [360]	validation_0-merror:0.12550
# [361]	validation_0-merror:0.12566
# [362]	validation_0-merror:0.12597
# [363]	validation_0-merror:0.12602
# [364]	validation_0-merror:0.12612
# [365]	validation_0-merror:0.12597
# [366]	validation_0-merror:0.12581
# [367]	validation_0-merror:0.12571
# [368]	validation_0-merror:0.12571
# [369]	validation_0-merror:0.12602
# [370]	validation_0-merror:0.12607
# [371]	validation_0-merror:0.12597
# [372]	validation_0-merror:0.12592
# [373]	validation_0-merror:0.12592
# [374]	validation_0-merror:0.12576
# [375]	validation_0-merror:0.12581
# [376]	validation_0-merror:0.12576
# [377]	validation_0-merror:0.12597
# [378]	validation_0-merror:0.12612
# [379]	validation_0-merror:0.12628
# [380]	validation_0-merror:0.12623
# [381]	validation_0-merror:0.12633
# [382]	validation_0-merror:0.12628
# [383]	validation_0-merror:0.12623
# [384]	validation_0-merror:0.12612
# [385]	validation_0-merror:0.12607
# [386]	validation_0-merror:0.12617
# [387]	validation_0-merror:0.12607
# [388]	validation_0-merror:0.12612
# [389]	validation_0-merror:0.12623
# [390]	validation_0-merror:0.12623
# [391]	validation_0-merror:0.12623
# [392]	validation_0-merror:0.12566
# [393]	validation_0-merror:0.12612
# [394]	validation_0-merror:0.12571
# [395]	validation_0-merror:0.12617
# [396]	validation_0-merror:0.12612
# [397]	validation_0-merror:0.12592
# [398]	validation_0-merror:0.12592
# [399]	validation_0-merror:0.12602
# [400]	validation_0-merror:0.12597
# [401]	validation_0-merror:0.12607
# [402]	validation_0-merror:0.12597
# [403]	validation_0-merror:0.12592
# [404]	validation_0-merror:0.12586
# [405]	validation_0-merror:0.12597
# [406]	validation_0-merror:0.12602
# [407]	validation_0-merror:0.12592
# [408]	validation_0-merror:0.12576
# [409]	validation_0-merror:0.12576
# [410]	validation_0-merror:0.12581
# [411]	validation_0-merror:0.12571
# [412]	validation_0-merror:0.12581
# [413]	validation_0-merror:0.12576
# [414]	validation_0-merror:0.12571
# [415]	validation_0-merror:0.12566
# [416]	validation_0-merror:0.12566
# [417]	validation_0-merror:0.12576
# [418]	validation_0-merror:0.12566
# [419]	validation_0-merror:0.12566
# [420]	validation_0-merror:0.12592
# [421]	validation_0-merror:0.12602
# [422]	validation_0-merror:0.12612
# [423]	validation_0-merror:0.12592
# [424]	validation_0-merror:0.12597
# [425]	validation_0-merror:0.12571
# [426]	validation_0-merror:0.12581
# [427]	validation_0-merror:0.12592
# [428]	validation_0-merror:0.12602
# [429]	validation_0-merror:0.12581
# [430]	validation_0-merror:0.12555
# [431]	validation_0-merror:0.12560
# [432]	validation_0-merror:0.12586
# [433]	validation_0-merror:0.12581
# [434]	validation_0-merror:0.12576
# [435]	validation_0-merror:0.12566
# [436]	validation_0-merror:0.12576
# [437]	validation_0-merror:0.12571
# [438]	validation_0-merror:0.12581
# [439]	validation_0-merror:0.12592
# [440]	validation_0-merror:0.12597
# [441]	validation_0-merror:0.12586
# [442]	validation_0-merror:0.12566
# [443]	validation_0-merror:0.12566
# [444]	validation_0-merror:0.12560
# [445]	validation_0-merror:0.12571
# [446]	validation_0-merror:0.12586
# [447]	validation_0-merror:0.12560
# [448]	validation_0-merror:0.12581
# [449]	validation_0-merror:0.12571
# [450]	validation_0-merror:0.12581
# [451]	validation_0-merror:0.12586
# [452]	validation_0-merror:0.12597
# [453]	validation_0-merror:0.12592
# [454]	validation_0-merror:0.12617
# [455]	validation_0-merror:0.12612
# [456]	validation_0-merror:0.12623
# [457]	validation_0-merror:0.12633
# [458]	validation_0-merror:0.12638
# [459]	validation_0-merror:0.12602
# [460]	validation_0-merror:0.12623
# [461]	validation_0-merror:0.12628
# [462]	validation_0-merror:0.12612
# [463]	validation_0-merror:0.12602
# [464]	validation_0-merror:0.12592
# [465]	validation_0-merror:0.12581
# [466]	validation_0-merror:0.12602
# [467]	validation_0-merror:0.12617
# [468]	validation_0-merror:0.12628
# [469]	validation_0-merror:0.12607
# [470]	validation_0-merror:0.12597
# [471]	validation_0-merror:0.12597
# [472]	validation_0-merror:0.12602
# [473]	validation_0-merror:0.12586
# [474]	validation_0-merror:0.12597
# [475]	validation_0-merror:0.12592
# [476]	validation_0-merror:0.12597
# [477]	validation_0-merror:0.12586
# [478]	validation_0-merror:0.12592
# [479]	validation_0-merror:0.12581
# [480]	validation_0-merror:0.12581
# [481]	validation_0-merror:0.12592
# [482]	validation_0-merror:0.12566
# [483]	validation_0-merror:0.12586
# [484]	validation_0-merror:0.12586
# [485]	validation_0-merror:0.12597
# [486]	validation_0-merror:0.12607
# [487]	validation_0-merror:0.12612
# [488]	validation_0-merror:0.12602
# [489]	validation_0-merror:0.12592
# [490]	validation_0-merror:0.12581
# [491]	validation_0-merror:0.12576
# [492]	validation_0-merror:0.12581
# [493]	validation_0-merror:0.12566
# [494]	validation_0-merror:0.12560
# [495]	validation_0-merror:0.12571
# [496]	validation_0-merror:0.12571
# [497]	validation_0-merror:0.12550
# [498]	validation_0-merror:0.12545
# [499]	validation_0-merror:0.12555
# [500]	validation_0-merror:0.12550
# [501]	validation_0-merror:0.12534
# [502]	validation_0-merror:0.12534
# [503]	validation_0-merror:0.12529
# [504]	validation_0-merror:0.12545
# [505]	validation_0-merror:0.12540
# [506]	validation_0-merror:0.12555
# [507]	validation_0-merror:0.12545
# [508]	validation_0-merror:0.12540
# [509]	validation_0-merror:0.12571
# [510]	validation_0-merror:0.12571
# [511]	validation_0-merror:0.12560
# [512]	validation_0-merror:0.12555
# [513]	validation_0-merror:0.12571
# [514]	validation_0-merror:0.12560
# [515]	validation_0-merror:0.12545
# [516]	validation_0-merror:0.12555
# [517]	validation_0-merror:0.12540
# [518]	validation_0-merror:0.12545
# [519]	validation_0-merror:0.12555
# [520]	validation_0-merror:0.12555
# [521]	validation_0-merror:0.12550
# [522]	validation_0-merror:0.12555
# [523]	validation_0-merror:0.12566
# [524]	validation_0-merror:0.12550
# [525]	validation_0-merror:0.12555
# [526]	validation_0-merror:0.12550
# [527]	validation_0-merror:0.12545
# [528]	validation_0-merror:0.12560
# [529]	validation_0-merror:0.12550
# [530]	validation_0-merror:0.12555
# [531]	validation_0-merror:0.12545
# [532]	validation_0-merror:0.12555
# [533]	validation_0-merror:0.12560
# [534]	validation_0-merror:0.12571
# [535]	validation_0-merror:0.12581
# [536]	validation_0-merror:0.12566
# [537]	validation_0-merror:0.12566
# [538]	validation_0-merror:0.12581
# [539]	validation_0-merror:0.12576
# [540]	validation_0-merror:0.12571
# [541]	validation_0-merror:0.12571
# [542]	validation_0-merror:0.12560
# [543]	validation_0-merror:0.12586
# [544]	validation_0-merror:0.12576
# [545]	validation_0-merror:0.12566
# [546]	validation_0-merror:0.12576
# [547]	validation_0-merror:0.12592
# [548]	validation_0-merror:0.12581
# [549]	validation_0-merror:0.12586
# [550]	validation_0-merror:0.12581
# [551]	validation_0-merror:0.12592
# [552]	validation_0-merror:0.12597
# [553]	validation_0-merror:0.12586
# [554]	validation_0-merror:0.12597
# [555]	validation_0-merror:0.12592
# [556]	validation_0-merror:0.12581
# [557]	validation_0-merror:0.12566
# [558]	validation_0-merror:0.12555
# [559]	validation_0-merror:0.12550
# [560]	validation_0-merror:0.12550
# [561]	validation_0-merror:0.12550
# [562]	validation_0-merror:0.12545
# [563]	validation_0-merror:0.12545
# [564]	validation_0-merror:0.12555
# [565]	validation_0-merror:0.12566
# [566]	validation_0-merror:0.12576
# [567]	validation_0-merror:0.12576
# [568]	validation_0-merror:0.12566
# [569]	validation_0-merror:0.12566
# [570]	validation_0-merror:0.12566
# [571]	validation_0-merror:0.12576
# [572]	validation_0-merror:0.12560
# [573]	validation_0-merror:0.12571
# [574]	validation_0-merror:0.12576
# [575]	validation_0-merror:0.12560
# [576]	validation_0-merror:0.12566
# [577]	validation_0-merror:0.12560
# [578]	validation_0-merror:0.12560
# [579]	validation_0-merror:0.12555
# [580]	validation_0-merror:0.12545
# [581]	validation_0-merror:0.12560
# [582]	validation_0-merror:0.12550
# [583]	validation_0-merror:0.12576
# [584]	validation_0-merror:0.12581
# [585]	validation_0-merror:0.12560
# [586]	validation_0-merror:0.12566
# [587]	validation_0-merror:0.12560
# [588]	validation_0-merror:0.12560
# [589]	validation_0-merror:0.12597
# [590]	validation_0-merror:0.12597
# [591]	validation_0-merror:0.12597
# [592]	validation_0-merror:0.12581
# [593]	validation_0-merror:0.12581
# [594]	validation_0-merror:0.12566
# [595]	validation_0-merror:0.12555
# [596]	validation_0-merror:0.12586
# [597]	validation_0-merror:0.12607
# [598]	validation_0-merror:0.12607
# [599]	validation_0-merror:0.12597
# [600]	validation_0-merror:0.12602
# [601]	validation_0-merror:0.12592
# [602]	validation_0-merror:0.12592
# [603]	validation_0-merror:0.12571
# [604]	validation_0-merror:0.12581
# [605]	validation_0-merror:0.12597
# [606]	validation_0-merror:0.12612
# [607]	validation_0-merror:0.12602
# [608]	validation_0-merror:0.12586
# [609]	validation_0-merror:0.12586
# [610]	validation_0-merror:0.12597
# [611]	validation_0-merror:0.12597
# [612]	validation_0-merror:0.12597
# [613]	validation_0-merror:0.12597
# [614]	validation_0-merror:0.12581
# [615]	validation_0-merror:0.12586
# [616]	validation_0-merror:0.12571
# [617]	validation_0-merror:0.12576
# [618]	validation_0-merror:0.12576
# [619]	validation_0-merror:0.12576
# [620]	validation_0-merror:0.12581
# [621]	validation_0-merror:0.12550
# [622]	validation_0-merror:0.12566
# [623]	validation_0-merror:0.12566
# [624]	validation_0-merror:0.12571
# [625]	validation_0-merror:0.12571
# [626]	validation_0-merror:0.12571
# [627]	validation_0-merror:0.12560
# [628]	validation_0-merror:0.12550
# [629]	validation_0-merror:0.12560
# [630]	validation_0-merror:0.12550
# [631]	validation_0-merror:0.12571
# [632]	validation_0-merror:0.12576
# [633]	validation_0-merror:0.12576
# [634]	validation_0-merror:0.12581
# [635]	validation_0-merror:0.12581
# [636]	validation_0-merror:0.12576
# [637]	validation_0-merror:0.12576
# [638]	validation_0-merror:0.12571
# [639]	validation_0-merror:0.12566
# [640]	validation_0-merror:0.12566
# [641]	validation_0-merror:0.12550
# [642]	validation_0-merror:0.12566
# [643]	validation_0-merror:0.12560
# [644]	validation_0-merror:0.12571
# [645]	validation_0-merror:0.12566
# [646]	validation_0-merror:0.12566
# [647]	validation_0-merror:0.12555
# [648]	validation_0-merror:0.12560
# [649]	validation_0-merror:0.12571
# [650]	validation_0-merror:0.12560
# [651]	validation_0-merror:0.12571
# [652]	validation_0-merror:0.12566
# [653]	validation_0-merror:0.12560
# [654]	validation_0-merror:0.12560
# [655]	validation_0-merror:0.12560
# [656]	validation_0-merror:0.12560
# [657]	validation_0-merror:0.12571
# [658]	validation_0-merror:0.12566
# [659]	validation_0-merror:0.12571
# [660]	validation_0-merror:0.12586
# [661]	validation_0-merror:0.12555
# [662]	validation_0-merror:0.12566
# [663]	validation_0-merror:0.12571
# [664]	validation_0-merror:0.12560
# [665]	validation_0-merror:0.12566
# [666]	validation_0-merror:0.12560
# [667]	validation_0-merror:0.12555
# [668]	validation_0-merror:0.12545
# [669]	validation_0-merror:0.12545
# [670]	validation_0-merror:0.12534
# [671]	validation_0-merror:0.12529
# [672]	validation_0-merror:0.12534
# [673]	validation_0-merror:0.12534
# [674]	validation_0-merror:0.12540
# [675]	validation_0-merror:0.12540
# [676]	validation_0-merror:0.12529
# [677]	validation_0-merror:0.12524
# [678]	validation_0-merror:0.12519
# [679]	validation_0-merror:0.12529
# [680]	validation_0-merror:0.12519
# [681]	validation_0-merror:0.12524
# [682]	validation_0-merror:0.12529
# [683]	validation_0-merror:0.12524
# [684]	validation_0-merror:0.12524
# [685]	validation_0-merror:0.12503
# [686]	validation_0-merror:0.12519
# [687]	validation_0-merror:0.12503
# [688]	validation_0-merror:0.12498
# [689]	validation_0-merror:0.12482
# [690]	validation_0-merror:0.12514
# [691]	validation_0-merror:0.12493
# [692]	validation_0-merror:0.12503
# [693]	validation_0-merror:0.12498
# [694]	validation_0-merror:0.12488
# [695]	validation_0-merror:0.12493
# [696]	validation_0-merror:0.12508
# [697]	validation_0-merror:0.12508
# [698]	validation_0-merror:0.12498
# [699]	validation_0-merror:0.12503
# [700]	validation_0-merror:0.12524
# [701]	validation_0-merror:0.12524
# [702]	validation_0-merror:0.12524
# [703]	validation_0-merror:0.12514
# [704]	validation_0-merror:0.12508
# [705]	validation_0-merror:0.12488
# [706]	validation_0-merror:0.12488
# [707]	validation_0-merror:0.12493
# [708]	validation_0-merror:0.12488
# [709]	validation_0-merror:0.12462
# [710]	validation_0-merror:0.12462
# [711]	validation_0-merror:0.12467
# [712]	validation_0-merror:0.12467
# [713]	validation_0-merror:0.12467
# [714]	validation_0-merror:0.12467
# [715]	validation_0-merror:0.12467
# [716]	validation_0-merror:0.12467
# [717]	validation_0-merror:0.12462
# [718]	validation_0-merror:0.12462
# [719]	validation_0-merror:0.12472
# [720]	validation_0-merror:0.12482
# [721]	validation_0-merror:0.12477
# [722]	validation_0-merror:0.12472
# [723]	validation_0-merror:0.12457
# [724]	validation_0-merror:0.12451
# [725]	validation_0-merror:0.12441
# [726]	validation_0-merror:0.12446
# [727]	validation_0-merror:0.12457
# [728]	validation_0-merror:0.12451
# [729]	validation_0-merror:0.12451
# [730]	validation_0-merror:0.12436
# [731]	validation_0-merror:0.12425
# [732]	validation_0-merror:0.12441
# [733]	validation_0-merror:0.12431
# [734]	validation_0-merror:0.12462
# [735]	validation_0-merror:0.12477
# [736]	validation_0-merror:0.12467
# [737]	validation_0-merror:0.12462
# [738]	validation_0-merror:0.12436
# [739]	validation_0-merror:0.12446
# [740]	validation_0-merror:0.12436
# [741]	validation_0-merror:0.12431
# [742]	validation_0-merror:0.12436
# [743]	validation_0-merror:0.12425
# [744]	validation_0-merror:0.12425
# [745]	validation_0-merror:0.12446
# [746]	validation_0-merror:0.12441
# [747]	validation_0-merror:0.12441
# [748]	validation_0-merror:0.12446
# [749]	validation_0-merror:0.12441
# [750]	validation_0-merror:0.12441
# [751]	validation_0-merror:0.12425
# [752]	validation_0-merror:0.12431
# [753]	validation_0-merror:0.12431
# [754]	validation_0-merror:0.12425
# [755]	validation_0-merror:0.12431
# [756]	validation_0-merror:0.12436
# [757]	validation_0-merror:0.12441
# [758]	validation_0-merror:0.12436
# [759]	validation_0-merror:0.12425
# [760]	validation_0-merror:0.12425
# [761]	validation_0-merror:0.12425
# [762]	validation_0-merror:0.12436
# [763]	validation_0-merror:0.12451
# [764]	validation_0-merror:0.12462
# [765]	validation_0-merror:0.12467
# [766]	validation_0-merror:0.12467
# [767]	validation_0-merror:0.12477
# [768]	validation_0-merror:0.12477
# [769]	validation_0-merror:0.12493
# [770]	validation_0-merror:0.12482
# [771]	validation_0-merror:0.12467
# [772]	validation_0-merror:0.12477
# [773]	validation_0-merror:0.12467
# [774]	validation_0-merror:0.12462
# [775]	validation_0-merror:0.12457
# [776]	validation_0-merror:0.12451
# [777]	validation_0-merror:0.12451
# [778]	validation_0-merror:0.12441
# [779]	validation_0-merror:0.12441
# [780]	validation_0-merror:0.12441
# [781]	validation_0-merror:0.12441
# [782]	validation_0-merror:0.12425
# [783]	validation_0-merror:0.12431
# [784]	validation_0-merror:0.12431
# [785]	validation_0-merror:0.12431
# [786]	validation_0-merror:0.12446
# [787]	validation_0-merror:0.12451
# [788]	validation_0-merror:0.12446
# [789]	validation_0-merror:0.12457
# [790]	validation_0-merror:0.12467
# [791]	validation_0-merror:0.12467
# [792]	validation_0-merror:0.12467
# [793]	validation_0-merror:0.12472
# [794]	validation_0-merror:0.12477
# [795]	validation_0-merror:0.12462
# [796]	validation_0-merror:0.12451
# [797]	validation_0-merror:0.12446
# [798]	validation_0-merror:0.12457
# [799]	validation_0-merror:0.12462
# [800]	validation_0-merror:0.12457
# [801]	validation_0-merror:0.12457
# [802]	validation_0-merror:0.12467
# [803]	validation_0-merror:0.12472
# [804]	validation_0-merror:0.12451
# [805]	validation_0-merror:0.12467
# [806]	validation_0-merror:0.12477
# [807]	validation_0-merror:0.12488
# [808]	validation_0-merror:0.12488
# [809]	validation_0-merror:0.12477
# [810]	validation_0-merror:0.12467
# [811]	validation_0-merror:0.12467
# [812]	validation_0-merror:0.12472
# [813]	validation_0-merror:0.12451
# [814]	validation_0-merror:0.12451
# [815]	validation_0-merror:0.12467
# [816]	validation_0-merror:0.12477
# [817]	validation_0-merror:0.12488
# [818]	validation_0-merror:0.12493
# [819]	validation_0-merror:0.12488
# [820]	validation_0-merror:0.12477
# [821]	validation_0-merror:0.12488
# [822]	validation_0-merror:0.12488
# [823]	validation_0-merror:0.12493
# [824]	validation_0-merror:0.12477
# [825]	validation_0-merror:0.12493
# [826]	validation_0-merror:0.12462
# [827]	validation_0-merror:0.12477
# [828]	validation_0-merror:0.12477
# [829]	validation_0-merror:0.12467
# [830]	validation_0-merror:0.12457
# [831]	validation_0-merror:0.12451
# [832]	validation_0-merror:0.12467
# [833]	validation_0-merror:0.12477
# [834]	validation_0-merror:0.12482
# [835]	validation_0-merror:0.12472
# [836]	validation_0-merror:0.12472
# [837]	validation_0-merror:0.12477
# [838]	validation_0-merror:0.12451
# [839]	validation_0-merror:0.12451
# [840]	validation_0-merror:0.12462
# [841]	validation_0-merror:0.12462
# [842]	validation_0-merror:0.12451
# [843]	validation_0-merror:0.12431
# [844]	validation_0-merror:0.12425
# [845]	validation_0-merror:0.12415
# [846]	validation_0-merror:0.12394
# [847]	validation_0-merror:0.12399
# [848]	validation_0-merror:0.12399
# [849]	validation_0-merror:0.12405
# [850]	validation_0-merror:0.12394
# [851]	validation_0-merror:0.12394
# [852]	validation_0-merror:0.12405
# [853]	validation_0-merror:0.12394
# [854]	validation_0-merror:0.12394
# [855]	validation_0-merror:0.12384
# [856]	validation_0-merror:0.12379
# [857]	validation_0-merror:0.12379
# [858]	validation_0-merror:0.12394
# [859]	validation_0-merror:0.12394
# [860]	validation_0-merror:0.12399
# [861]	validation_0-merror:0.12399
# [862]	validation_0-merror:0.12389
# [863]	validation_0-merror:0.12384
# [864]	validation_0-merror:0.12405
# [865]	validation_0-merror:0.12410
# [866]	validation_0-merror:0.12405
# [867]	validation_0-merror:0.12405
# [868]	validation_0-merror:0.12399
# [869]	validation_0-merror:0.12399
# [870]	validation_0-merror:0.12399
# [871]	validation_0-merror:0.12410
# [872]	validation_0-merror:0.12415
# [873]	validation_0-merror:0.12420
# [874]	validation_0-merror:0.12410
# [875]	validation_0-merror:0.12410
# [876]	validation_0-merror:0.12405
# [877]	validation_0-merror:0.12384
# [878]	validation_0-merror:0.12394
# [879]	validation_0-merror:0.12384
# [880]	validation_0-merror:0.12399
# [881]	validation_0-merror:0.12410
# [882]	validation_0-merror:0.12389
# [883]	validation_0-merror:0.12379
# [884]	validation_0-merror:0.12389
# [885]	validation_0-merror:0.12379
# [886]	validation_0-merror:0.12399
# [887]	validation_0-merror:0.12410
# [888]	validation_0-merror:0.12399
# [889]	validation_0-merror:0.12399
# [890]	validation_0-merror:0.12410
# [891]	validation_0-merror:0.12405
# [892]	validation_0-merror:0.12415
# [893]	validation_0-merror:0.12394
# [894]	validation_0-merror:0.12394
# [895]	validation_0-merror:0.12384
# [896]	validation_0-merror:0.12384
# [897]	validation_0-merror:0.12394
# [898]	validation_0-merror:0.12384
# [899]	validation_0-merror:0.12405
# [900]	validation_0-merror:0.12415
# [901]	validation_0-merror:0.12410
# [902]	validation_0-merror:0.12420
# [903]	validation_0-merror:0.12410
# [904]	validation_0-merror:0.12399
# [905]	validation_0-merror:0.12425
# [906]	validation_0-merror:0.12405
# [907]	validation_0-merror:0.12389
# [908]	validation_0-merror:0.12394
# [909]	validation_0-merror:0.12389
# [910]	validation_0-merror:0.12389
# [911]	validation_0-merror:0.12399
# [912]	validation_0-merror:0.12405
# [913]	validation_0-merror:0.12410
# [914]	validation_0-merror:0.12394
# [915]	validation_0-merror:0.12389
# [916]	validation_0-merror:0.12389
# [917]	validation_0-merror:0.12384
# [918]	validation_0-merror:0.12368
# [919]	validation_0-merror:0.12363
# [920]	validation_0-merror:0.12347
# [921]	validation_0-merror:0.12337
# [922]	validation_0-merror:0.12363
# [923]	validation_0-merror:0.12363
# [924]	validation_0-merror:0.12363
# [925]	validation_0-merror:0.12368
# [926]	validation_0-merror:0.12358
# [927]	validation_0-merror:0.12368
# [928]	validation_0-merror:0.12363
# [929]	validation_0-merror:0.12368
# [930]	validation_0-merror:0.12389
# [931]	validation_0-merror:0.12379
# [932]	validation_0-merror:0.12389
# [933]	validation_0-merror:0.12394
# [934]	validation_0-merror:0.12405
# [935]	validation_0-merror:0.12420
# [936]	validation_0-merror:0.12399
# [937]	validation_0-merror:0.12405
# [938]	validation_0-merror:0.12394
# [939]	validation_0-merror:0.12389
# [940]	validation_0-merror:0.12410
# [941]	validation_0-merror:0.12410
# [942]	validation_0-merror:0.12399
# [943]	validation_0-merror:0.12410
# [944]	validation_0-merror:0.12399
# [945]	validation_0-merror:0.12415
# [946]	validation_0-merror:0.12425
# [947]	validation_0-merror:0.12425
# [948]	validation_0-merror:0.12420
# [949]	validation_0-merror:0.12420
# [950]	validation_0-merror:0.12425
# [951]	validation_0-merror:0.12410
# [952]	validation_0-merror:0.12415
# [953]	validation_0-merror:0.12415
# [954]	validation_0-merror:0.12410
# [955]	validation_0-merror:0.12415
# [956]	validation_0-merror:0.12405
# [957]	validation_0-merror:0.12410
# [958]	validation_0-merror:0.12410
# [959]	validation_0-merror:0.12420
# [960]	validation_0-merror:0.12415
# [961]	validation_0-merror:0.12415
# [962]	validation_0-merror:0.12405
# [963]	validation_0-merror:0.12410
# [964]	validation_0-merror:0.12394
# [965]	validation_0-merror:0.12389
# [966]	validation_0-merror:0.12405
# [967]	validation_0-merror:0.12415
# [968]	validation_0-merror:0.12410
# [969]	validation_0-merror:0.12420
# [970]	validation_0-merror:0.12410
# [971]	validation_0-merror:0.12415
# [972]	validation_0-merror:0.12415
# [973]	validation_0-merror:0.12394
# [974]	validation_0-merror:0.12405
# [975]	validation_0-merror:0.12415
# [976]	validation_0-merror:0.12389
# [977]	validation_0-merror:0.12399
# [978]	validation_0-merror:0.12394
# [979]	validation_0-merror:0.12399
# [980]	validation_0-merror:0.12405
# [981]	validation_0-merror:0.12394
# [982]	validation_0-merror:0.12394
# [983]	validation_0-merror:0.12384
# [984]	validation_0-merror:0.12389
# [985]	validation_0-merror:0.12405
# [986]	validation_0-merror:0.12405
# [987]	validation_0-merror:0.12389
# [988]	validation_0-merror:0.12394
# [989]	validation_0-merror:0.12379
# [990]	validation_0-merror:0.12373
# [991]	validation_0-merror:0.12379
# [992]	validation_0-merror:0.12379
# [993]	validation_0-merror:0.12368
# [994]	validation_0-merror:0.12368
# [995]	validation_0-merror:0.12353
# [996]	validation_0-merror:0.12358
# [997]	validation_0-merror:0.12373
# [998]	validation_0-merror:0.12394
# [999]	validation_0-merror:0.12384

# %%
from datetime import datetime

print("valid score:", evaluate)
pred = ml_predict(model, test)
submission['대출등급'] = ord_dict["대출등급"].inverse_transform(pred.reshape(-1, 1)).reshape(-1)

print(submission)

current_datetime = datetime.now().strftime("%y%m%d.%H%M")
print(current_datetime)

submission.to_csv(current_datetime+'.csv', index=False)
# Out:
# valid score: 0.8179394085534073
#                ID 대출등급
# 0      TEST_00000    B
# 1      TEST_00001    B
# 2      TEST_00002    A
# 3      TEST_00003    C
# 4      TEST_00004    C
# ...           ...  ...
# 64192  TEST_64192    D
# 64193  TEST_64193    D
# 64194  TEST_64194    D
# 64195  TEST_64195    C
# 64196  TEST_64196    A
#
# [64197 rows x 2 columns]
# 240124.1557
